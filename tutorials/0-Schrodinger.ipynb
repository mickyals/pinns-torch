# %% [markdown]
# ## Tutorial - 0: Continuous Forward Schrodinger
#
# Welcome to our first tutorial on Physics-Informed Neural Networks (PINNs) using `PyTorch Lightning` and our new package, **`pinnstorch`**! This guide aims to introduce you to the integration of deep learning and scientific computing via PINNs, which embed physical laws into neural network training.
#
# #### Overview:
#
# - **Mesh Generation and Sampling:** Understanding how to create and use meshes for training PINNs, crucial for defining the domain of our problem.
# - **Neural Network Model with PINNs:** How to build and structure a neural network for physical law integration.
# - **Physical Laws in Neural Networks:** Detailing the implementation of differential equations within the network using `pde_fn` and `output_fn`.
# - **Training and Validation:** Utilizing PyTorch Lightning’s Trainer to train our model, including defining the training data, initial conditions, and handling boundary conditions.
# - **Results Visualization:** Saving and analyzing the outcomes of your PINN models.

# %% [markdown]
# #### Install Libraries

# %%
# !pip install pinnstorch
# !pip install lightning
# Out:
# Requirement already satisfied: pinnstorch in c:\users\micke\onedrive - university of toronto\pinns-torch (0.1.2)
# Requirement already satisfied: hydra-core in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.3.2)
# Requirement already satisfied: scipy in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.13.1)
# Requirement already satisfied: pyDOE in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (0.3.8)
# Requirement already satisfied: matplotlib in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (3.10.0)
# Requirement already satisfied: rootutils in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.0.7)
# Requirement already satisfied: tqdm in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (4.66.5)
# Requirement already satisfied: rich in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (13.7.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (4.9.3)
# Requirement already satisfied: packaging in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.15.1)
# Requirement already satisfied: python-dotenv>=0.20.0 in c:\users\micke\anaconda3\lib\site-packages (from rootutils->pinnstorch) (0.21.0)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm->pinnstorch) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\micke\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->pinnstorch) (0.1.0)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\micke\anaconda3\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core->pinnstorch) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\micke\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pinnstorch) (1.16.0)
# Requirement already satisfied: lightning in c:\users\micke\anaconda3\lib\site-packages (2.5.5)
# Requirement already satisfied: PyYAML<8.0,>5.4 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (0.11.9)
# Requirement already satisfied: packaging<27.0,>=20.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.3.1)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (1.4.0.post0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.66.5)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.11.0)
# Requirement already satisfied: pytorch-lightning in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (3.10.5)
# Requirement already satisfied: setuptools in c:\users\micke\anaconda3\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: filelock in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.13.1)
# Requirement already satisfied: sympy in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.2)
# Requirement already satisfied: networkx in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.4)
# Requirement already satisfied: numpy>1.20.0 in c:\users\micke\anaconda3\lib\site-packages (from torchmetrics<3.0,>0.7.0->lightning) (1.26.4)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\micke\anaconda3\lib\site-packages (from sympy->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (3.7)

# %% [markdown]
# #### Import Libraries

# %%
from typing import Dict

import torch
import numpy as np
import lightning.pytorch as pl

import pinnstorch
from pinnstorch.models.net.activations import SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

# %% [markdown]
# ### Define Mesh
#
# Physics-Informed Neural Networks (PINNs) require a discretized domain (mesh) over which the physical equations are solved. In `pinnstorch`, there are primarily two approaches to define this mesh:
#
#
# - **Defining Time and Spatial Domains Separately:** Here, we use `pinnstorch.data.TimeDomain` and `pinnstorch.data.Interval` for creating 1-D spatial domains. These domains are then used to define a `pinnstorch.data.Mesh`.
#
# - **Defining Point Clouds:** This method involves directly utilizing spatio-temporal data (e.g., from experiments or other simulations) to create a mesh using `pinnstorch.data.PointCloud`.
#
# Both approaches should ideally yield the same results.

# %% [markdown]
# #### Option 1: Defining Mesh with Separate Time and Spatial Domains
#
# We start by defining a function to read and preprocess the solution data from a file. The output should be a dictionary.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in Mesh class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")
    exact = data["uu"] # complex number shape N x T
    exact_u = np.real(exact) # N x T # real part
    exact_v = np.imag(exact) # N x T # imaginary part
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T # absolute value ----> ||X|| = sqrt(x^2 + y^2)
    return {"u": exact_u, "v": exact_v, "h": exact_h} # return dict of solutions {u:real, v:imag, h:absolute value}

# %% [markdown]
# Now, define the time and spatial domains for mesh generation. The choice of these parameters depends on the specific problem being solved and should be set accordingly.

# %%
time_domain = pinnstorch.data.TimeDomain(t_interval=[0, 1.57079633], t_points = 201)
spatial_domain = pinnstorch.data.Interval(x_interval= [-5, 4.9609375], shape = [256, 1])

# %%
help(time_domain)
time_domain
# Out:
# Help on TimeDomain in module pinnstorch.data.domains.time object:
#
# class TimeDomain(builtins.object)
#  |  TimeDomain(t_interval, t_points: int)
#  |
#  |  Initialize a time domain.
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, idx)
#  |      Get a specific time point from the time domain using indexing.
#  |
#  |      :param idx: The index of the desired time point.
#  |      :return: The time value at the specified index.
#  |
#  |  __init__(self, t_interval, t_points: int)
#  |      Initialize a TimeDomain object to represent a time domain.
#  |
#  |      :param t_interval: A tuple or list representing the time interval [start_time, end_time].
#  |      :param t_points: The number of time points to discretize the interval.
#  |
#  |  __len__(self)
#  |      Get the length of the time domain.
#  |
#  |      :return: The number of time points in the time domain.
#  |
#  |  generate_mesh(self, spatial_points)
#  |      Generate a mesh of time based on number of spatial points.
#  |
#  |      :param spatial_points: The number of spatial points.
#  |      :return: A mesh of time and spatial points.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# The mesh is then defined using the time and spatial domains along with the read_data_fn function.

# %%
mesh = pinnstorch.data.Mesh(root_dir='../data',
                            read_data_fn=read_data_fn,
                            spatial_domain = spatial_domain,
                            time_domain = time_domain)

# %% [markdown]
# #### Option 2: Using Point Clouds
#
# For scenarios where the spatial and temporal data along with solutions are directly available (e.g., from experimental measurements), we can create a mesh using `pinnstorch.data.PointCloud`.
#
# **Note:** It's crucial to format the spatial and temporal domain dimensions correctly. Specifically:
#
# - **Spatial Domain:** Each axis should be structured in the shape of $(N \times 1)$, where $N$ represents the number of spatial points.
# - **Time Domain:** This should be formatted as $(T \times 1)$, where $T$ indicates the number of time steps.
# - **Solution Data:** Each solution variable (e.g., temperature, velocity) should be in the shape of $(N \times T)$, aligning with the spatial and temporal points.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in PointCloud class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")

    x = data["x"].T  # N x 1
    t = data["tt"].T  # T x 1
    
    exact = data["uu"]
    exact_u = np.real(exact) # N x T
    exact_v = np.imag(exact) # N x T
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T

    print(f" x has {x.shape} shape with min: {x.min()}, max: {x.max()}")
    print(f" t has {t.shape} shape with min: {t.min()}, max: {t.max()}")
    print(f"  exact_u {exact_u.shape} shape with min: {exact_u.min()}, max: {exact_u.max()}")
    print(f" exact_v {exact_v.shape} shape with min: {exact_v.min()}, max: {exact_v.max()}")
    print(f" exact_h  {exact_h.shape} shape with min: {exact_h.min()}, max: {exact_h.max()}")


    
    return pinnstorch.data.PointCloudData(
            spatial=[x], time=[t], solution={"u": exact_u, "v": exact_v, "h": exact_h}
    )

# %% [markdown]
# Now, mesh can be initalize with using the function and the directory to the folder of data.

# %%
mesh = pinnstorch.data.PointCloud(root_dir='./data',
                                  read_data_fn=read_data_fn)
# Out:
#  x has (256, 1) shape with min: -5.0, max: 4.9609375
#  t has (201, 1) shape with min: 0.0, max: 1.5707963267948966
#   exact_u (256, 201) shape with min: -3.932425448799453, max: 2.1998422786360754
#  exact_v (256, 201) shape with min: -3.4523031901896957, max: 2.754265786698505
#  exact_h  (256, 201) shape with min: 0.015981892796576278, max: 3.9987582390710266

# %% [markdown]
# ### Define Train datasets

# %% [markdown]
# For solving Schrodinger PDE, we have:
# - Initial condition
# - Periodic boundary condition
# - Collection points for the PDE.

# %% [markdown]
# #### Initial Condition
#
# Let's start with initial condition of the Schrodinger.
# $$ u(0, x) = 2 \text{sech}(x) $$
# $$ v(0, x) = 0 $$
#
# For defining initial condition, again we have two options.
#
# - **Sample from the data.**
# - **Defining a function for calculating initial condition.**

# %% [markdown]
# ##### Set number of samples

# %%
N0 = 50

# %% [markdown]
# ##### Option 1: Sample from the data

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        solution = ['u', 'v'])

# %% [markdown]
# ##### Option 2: Defining a function for calculating initial condition

# %% [markdown]
# The input of `initial_fun` should be the same as spatial domain of the problem.

# %%
def initial_fun(x):
    return {'u': 2*1/np.cosh(x), 'v': np.zeros_like(x)}

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        initial_fun = initial_fun,
                                        solution = ['u', 'v'])

# %% [markdown]
# The `solution` attribute in `pinnstorch.data.InitialCondition` specifies the solutions (`u` and `v` in our case) to be sampled for initial conditions.

# %% [markdown]
# #### Periodic Boundary Condition

# %% [markdown]
# The `pinnstorch.data.PeriodicBoundaryCondition` is used to sample periodic points from the upper and lower bounds of the spatial domain (mesh). The `derivative_order` parameter specifies the order of the derivative to be matched at these boundaries. In our case, for the Schrödinger equation, both the function and its first spatial derivative should match at the boundaries, hence `derivative_order = 1`.
#
#
# $$ u(t,-5) = u(t, 5), $$
# $$ v(t,-5) = v(t, 5), $$
# $$ u_x(t,-5) = u_x(t, 5),$$
# $$ v_x(t,-5) = v_x(t, 5) $$

# %%
N_b = 50
pe_b = pinnstorch.data.PeriodicBoundaryCondition(mesh = mesh,
                                                 num_sample = 50,
                                                 derivative_order = 1,
                                                 solution = ['u', 'v'])

# %% [markdown]
# #### Mesh Sampler for collection points and solutions
#
# In our problem, the partial differential equations (PDEs) governing the dynamics are given by:
#
# $$ f_u := u_t + 0.5v_{xx} + v(u^2 +v^2),$$
# $$ f_v := v_t + 0.5u_{xx} + u(u^2 +v^2) $$
#
# To find the solutions to these PDEs using a neural network, we must sample points from the domain at which the network will be trained to satisfy these equations. This sampling process is crucial for training our PINN. We utilize the `pinnstorch.data.MeshSampler` for this purpose, specifying the following:
#
# - **Number of Sample Points (N_f):** We choose to sample 20,000 points from the domain. This number is a balance between computational efficiency and the need for a sufficiently dense sampling to capture the dynamics of the PDEs.
# - **Mesh (mesh):** This parameter defines the spatial-temporal domain from which the points will be sampled.
# - **Collection Points:** We define `['f_u', 'f_v']` as the targets for our collection points. These are not direct outputs from the neural network but are derived from the network outputs and their derivatives (We will define `pde_fn` function later). The PINN will be trained such that these expressions tend towards zero, aligning with the PDE constraints.
#
# Here's the code to implement this sampler:

# %%
N_f = 20000
me_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                   num_sample = N_f,
                                   collection_points = ['f_v', 'f_u'])

# %% [markdown]
# ### Define Validation dataset
#
# For validation, we sample all points from the mesh to evaluate our model comprehensively. Model will be validated for solutions of `u`, `v`, and `h`.
#
# **Note:** If `num_sample` is not specified, the sampler will use the entire mesh for data sampling.

# %%
val_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                    solution = ['u', 'v', 'h'])

# %%
# SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

net = pinnstorch.models.FCN(layers = [2, 100, 100, 100, 100, 2],
                            output_names = ['u', 'v'],
                            lb=mesh.lb,
                            ub=mesh.ub,
                            activation="SINE",                  # use registry
                            activation_kwargs={'omega':5},    # extra params
                            initializer="SIREN",                # use registry
                            initializer_kwargs={'in_features': 2, 'omega':5}, # extra params
                            layer_type='BASE',
                            layer_kwargs={}
                             )

# %% [markdown]
# ### Define `pde_fn` and `output_fn` functions
#
# Now, we define `pde_fn` and `output_fn`.
# - **`output_fn`:** is applied to the network's output, adding any necessary post-processing computations. For example, in our case, `h(x,t) = u(x,t)**2 + v(x,t)**2`, thus, we define this equation in `output_fn`.
# - **`pde_fn`:** formulates the PDE constraints, which will be used by the `MeshSampler` to compute the loss at the collection points.

# %% [markdown]
# #### `output_fn` function
#
# **Note:** `output_fn` should always have these inputs:
# - **Outputs:** It is output of the network. In our case, this dictionary should have two output: `u` and `v`.
# - **Spatial domains:** These are the spatial domain variables. In our case, because our problem has 1-D spatial domain, the input just have `x`. For example, if we had 2-D space, we need another input for that dimention. For example, the inputs from `(outputs, x, t)` will be changed to `(outputs, x, y, t)`.
# - **Time domin:** The last input of `output_fn` function always should be time.

# %%
def output_fn(outputs: Dict[str, torch.Tensor],
              x: torch.Tensor,
              t: torch.Tensor):
    """Define `output_fn` function that will be applied to outputs of net."""

    outputs["h"] = torch.sqrt(outputs["u"] ** 2 + outputs["v"] ** 2)

    return outputs

# %% [markdown]
# #### `pde_fn` function
#
# The inputs are similar to `output_fn`. Only if we have extra variables for training (i.g. in inverse problems), we should add input at the end of inputs. For example, `(outputs, x, t)` will be `(outputs, x, t, extra_variable)`. `extra_variable` is always a dictionary.

# %%
def pde_fn(outputs: Dict[str, torch.Tensor],
           x: torch.Tensor,
           t: torch.Tensor):   
    """Define the partial differential equations (PDEs)."""
    u_x, u_t = pinnstorch.utils.gradient(outputs["u"], [x, t])
    v_x, v_t = pinnstorch.utils.gradient(outputs["v"], [x, t])

    u_xx = pinnstorch.utils.gradient(u_x, x)[0]
    v_xx = pinnstorch.utils.gradient(v_x, x)[0]

    outputs["f_u"] = u_t + 0.5 * v_xx + (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["v"]
    outputs["f_v"] = v_t - 0.5 * u_xx - (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["u"]

    return outputs

# %% [markdown]
# ### Define PINNDataModule and PINNModule
#
# To integrate with Lightning, we utilize two specialized modules:
#
# - `PINNDataModule` (inherited from `LightningDataModule`) manages data.
# - `PINNModule` (derived from `LightningModule`) handles the model, compilation, and various enhancements like AMP.

# %% [markdown]
# #### Define `PINNDataModule`
# Here, we define collection points, initial condition, and preiodic boundary condition as training datasets, and also, we set validation set. `PINNDataModule` is used for defining training, validation, prediction, and test datasets.

# %%
train_datasets = [me_s, in_c, pe_b]
val_dataset = val_s
datamodule = pinnstorch.data.PINNDataModule(train_datasets = [me_s, in_c, pe_b],
                                            val_dataset = val_dataset,
                                            pred_dataset = val_s)

# %% [markdown]
# #### Define `PINNModule`
#
# `PINNModule` handle several things. Here, we will explore the inputs of this class:
# - **net:**  The neural network.
# - **pde_fn:** The function representing the PDE to solve.
# - **optimizer:**  (Optional) The optimizer for training. The default is Adam
# - **loss_fn:** (Optional) The loss function to use, either "sse" or "mse". The default is "sse".
# - **scheduler:** (Optional) Learning rate scheduler. The default is None.
# - **scaler:** (Optional) Gradient scaler for AMP. The default is `torch.cuda.amp.GradScaler`.
# - **extra_variables:** (Optional) Extra variables in inverse problems. The default is None.
# - **output_fn:** (Optional) function to process the model's output. The default is None.
# - **runge_kutta:** (Optional) Runge-Kutta method for solving PDEs in discrete mode. The default is None.
# - **cudagraph_compile:** Flag to enable CUDA Graph compilation. It works only with a single GPU. The default is True.
# - **jit_compile:** (Optional) Flag to enable JIT compilation. The default is True.
# - **amp:** (Optional) Flag to enable Automatic Mixed Precision (AMP). The default is False.
# - **inline:** (Optional) Flag to enable inline mode in JIT compilation. The default is False.
#
# In this example, we initalize `PINNModule` with defined variables. We set Adam optimizer and try to compile the model with CUDA Graph. The loss function here is Mean Square Error (MSE).

# %%
model = pinnstorch.models.PINNModule(net = net,
                                     pde_fn = pde_fn,
                                     output_fn = output_fn,
                                     loss_fn = 'mse')

# %% [markdown]
# ### Setting Up the Trainer
#
# For training our model, we configure a trainer in PyTorch Lightning. Currently, our setup uses a single GPU, as models compiled with CUDA Graph don't support multiple GPUs yet. For a comprehensive understanding of the trainer's options and functionalities, refer to the [official documentation](https://lightning.ai/docs/pytorch/stable/api/lightning.pytorch.trainer.trainer.Trainer.html). For example, arguments that you can set are:
# - **accelerator:**  Supports passing different accelerator types such as `cpu`, `gpu`, `tpu`, `ipu`, `hpu`, `mps`, and `auto`.
# - **devices:** The devices to use. Can be set to a positive number (int or str), a sequence of device indices (list or str), the value -1 to indicate all available devices should be used, or "auto" for automatic selection based on the chosen accelerator. Default: "auto".
# - **max_epochs:** Stop training once this number of epochs is reached.
# - **max_steps:** Stop training after this number of steps.
# - ...
#
# In our example, we configure the trainer for CPU use, specifying one device:

# %%
trainer = pl.Trainer(accelerator='gpu', devices=1, max_epochs = 1000)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\lightning\pytorch\trainer\connectors\logger_connector\logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %% [markdown]
# ### Training

# %%
# %%time
trainer.fit(model=model, datamodule=datamodule)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 4080 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type       | Params | Mode
# -----------------------------------------------------
# 0 | net           | FCN        | 30.8 K | train
# 1 | train_loss    | MeanMetric | 0      | train
# 2 | val_loss      | MeanMetric | 0      | train
# 3 | val_error     | MeanMetric | 0      | train
# 4 | test_loss     | MeanMetric | 0      | train
# 5 | test_error    | MeanMetric | 0      | train
# 6 | val_loss_best | MinMetric  | 0      | train
# -----------------------------------------------------
# 30.8 K    Trainable params
# 0         Non-trainable params
# 30.8 K    Total params
# 0.123     Total estimated model params size (MB)
# 23        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:377: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# Epoch 0: 100%|██████████| 1/1 [00:02<00:00,  0.47it/s, v_num=40, train/loss_step=1.350]
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 86.21it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s, v_num=40, train/loss_step=1.090, val/loss=1.340, val/error_u=0.937, val/error_v=1.040, val/error_h=0.850, val/loss_best=1.340, train/loss_epoch=1.350]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 84.87it/s]
# Epoch 2: 100%|██████████| 1/1 [00:03<00:00,  0.28it/s, v_num=40, train/loss_step=0.581, val/loss=1.130, val/error_u=0.835, val/error_v=1.030, val/error_h=0.758, val/loss_best=1.130, train/loss_epoch=1.090]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 94.40it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 34.47it/s, v_num=40, train/loss_step=0.465, val/loss=1.060, val/error_u=0.814, val/error_v=1.020, val/error_h=0.720, val/loss_best=1.060, train/loss_epoch=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 76.83it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 31.83it/s, v_num=40, train/loss_step=0.409, val/loss=1.020, val/error_u=0.793, val/error_v=1.030, val/error_h=0.691, val/loss_best=1.020, train/loss_epoch=0.465]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.84it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 31.52it/s, v_num=40, train/loss_step=0.323, val/loss=0.972, val/error_u=0.778, val/error_v=1.030, val/error_h=0.660, val/loss_best=0.972, train/loss_epoch=0.409]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.66it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 35.55it/s, v_num=40, train/loss_step=0.259, val/loss=0.933, val/error_u=0.779, val/error_v=1.010, val/error_h=0.632, val/loss_best=0.933, train/loss_epoch=0.323]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.94it/s]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 34.98it/s, v_num=40, train/loss_step=0.235, val/loss=0.900, val/error_u=0.791, val/error_v=0.991, val/error_h=0.604, val/loss_best=0.900, train/loss_epoch=0.259]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 86.85it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 34.86it/s, v_num=40, train/loss_step=0.224, val/loss=0.879, val/error_u=0.800, val/error_v=0.972, val/error_h=0.586, val/loss_best=0.879, train/loss_epoch=0.235]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.24it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 34.25it/s, v_num=40, train/loss_step=0.216, val/loss=0.870, val/error_u=0.795, val/error_v=0.975, val/error_h=0.579, val/loss_best=0.870, train/loss_epoch=0.224]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.39it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 35.89it/s, v_num=40, train/loss_step=0.200, val/loss=0.871, val/error_u=0.782, val/error_v=0.993, val/error_h=0.580, val/loss_best=0.870, train/loss_epoch=0.216]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.48it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 33.98it/s, v_num=40, train/loss_step=0.174, val/loss=0.878, val/error_u=0.777, val/error_v=1.010, val/error_h=0.580, val/loss_best=0.870, train/loss_epoch=0.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.89it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 34.72it/s, v_num=40, train/loss_step=0.162, val/loss=0.884, val/error_u=0.782, val/error_v=1.020, val/error_h=0.576, val/loss_best=0.870, train/loss_epoch=0.174]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.60it/s]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 34.98it/s, v_num=40, train/loss_step=0.159, val/loss=0.881, val/error_u=0.787, val/error_v=1.020, val/error_h=0.569, val/loss_best=0.870, train/loss_epoch=0.162]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.92it/s]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 34.10it/s, v_num=40, train/loss_step=0.149, val/loss=0.870, val/error_u=0.786, val/error_v=1.020, val/error_h=0.559, val/loss_best=0.870, train/loss_epoch=0.159]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.87it/s]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 30.53it/s, v_num=40, train/loss_step=0.133, val/loss=0.857, val/error_u=0.782, val/error_v=1.020, val/error_h=0.546, val/loss_best=0.857, train/loss_epoch=0.149]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.21it/s]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 31.57it/s, v_num=40, train/loss_step=0.125, val/loss=0.848, val/error_u=0.780, val/error_v=1.030, val/error_h=0.531, val/loss_best=0.848, train/loss_epoch=0.133]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.64it/s]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 30.18it/s, v_num=40, train/loss_step=0.127, val/loss=0.844, val/error_u=0.783, val/error_v=1.040, val/error_h=0.518, val/loss_best=0.844, train/loss_epoch=0.125]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.87it/s]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 32.00it/s, v_num=40, train/loss_step=0.121, val/loss=0.844, val/error_u=0.789, val/error_v=1.040, val/error_h=0.509, val/loss_best=0.844, train/loss_epoch=0.127]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.75it/s]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 31.23it/s, v_num=40, train/loss_step=0.108, val/loss=0.845, val/error_u=0.796, val/error_v=1.040, val/error_h=0.502, val/loss_best=0.844, train/loss_epoch=0.121]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.84it/s]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 33.16it/s, v_num=40, train/loss_step=0.102, val/loss=0.846, val/error_u=0.802, val/error_v=1.040, val/error_h=0.497, val/loss_best=0.844, train/loss_epoch=0.108]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.64it/s]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 31.05it/s, v_num=40, train/loss_step=0.102, val/loss=0.847, val/error_u=0.806, val/error_v=1.050, val/error_h=0.491, val/loss_best=0.844, train/loss_epoch=0.102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.88it/s]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 31.18it/s, v_num=40, train/loss_step=0.0971, val/loss=0.845, val/error_u=0.806, val/error_v=1.050, val/error_h=0.482, val/loss_best=0.844, train/loss_epoch=0.102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.85it/s]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 29.98it/s, v_num=40, train/loss_step=0.0908, val/loss=0.843, val/error_u=0.801, val/error_v=1.070, val/error_h=0.475, val/loss_best=0.843, train/loss_epoch=0.0971]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 83.97it/s]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 33.46it/s, v_num=40, train/loss_step=0.0894, val/loss=0.842, val/error_u=0.796, val/error_v=1.080, val/error_h=0.468, val/loss_best=0.842, train/loss_epoch=0.0908]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.46it/s]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 33.47it/s, v_num=40, train/loss_step=0.0876, val/loss=0.842, val/error_u=0.796, val/error_v=1.080, val/error_h=0.463, val/loss_best=0.842, train/loss_epoch=0.0894]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 74.48it/s]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 31.61it/s, v_num=40, train/loss_step=0.0816, val/loss=0.844, val/error_u=0.804, val/error_v=1.080, val/error_h=0.460, val/loss_best=0.842, train/loss_epoch=0.0876]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.55it/s]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 33.47it/s, v_num=40, train/loss_step=0.0792, val/loss=0.849, val/error_u=0.815, val/error_v=1.080, val/error_h=0.457, val/loss_best=0.842, train/loss_epoch=0.0816]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.28it/s]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 29.84it/s, v_num=40, train/loss_step=0.0802, val/loss=0.853, val/error_u=0.822, val/error_v=1.080, val/error_h=0.455, val/loss_best=0.842, train/loss_epoch=0.0792]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.58it/s]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 31.38it/s, v_num=40, train/loss_step=0.0776, val/loss=0.856, val/error_u=0.824, val/error_v=1.080, val/error_h=0.453, val/loss_best=0.842, train/loss_epoch=0.0802]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.72it/s]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 27.40it/s, v_num=40, train/loss_step=0.0732, val/loss=0.858, val/error_u=0.822, val/error_v=1.090, val/error_h=0.449, val/loss_best=0.842, train/loss_epoch=0.0776]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.17it/s]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 30.33it/s, v_num=40, train/loss_step=0.0725, val/loss=0.860, val/error_u=0.821, val/error_v=1.100, val/error_h=0.445, val/loss_best=0.842, train/loss_epoch=0.0732]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 43.91it/s]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 31.22it/s, v_num=40, train/loss_step=0.0734, val/loss=0.863, val/error_u=0.822, val/error_v=1.110, val/error_h=0.442, val/loss_best=0.842, train/loss_epoch=0.0725]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.80it/s]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 29.59it/s, v_num=40, train/loss_step=0.0709, val/loss=0.867, val/error_u=0.825, val/error_v=1.110, val/error_h=0.441, val/loss_best=0.842, train/loss_epoch=0.0734]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.91it/s]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 31.60it/s, v_num=40, train/loss_step=0.0687, val/loss=0.871, val/error_u=0.831, val/error_v=1.110, val/error_h=0.441, val/loss_best=0.842, train/loss_epoch=0.0709]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.66it/s]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 31.57it/s, v_num=40, train/loss_step=0.0687, val/loss=0.876, val/error_u=0.836, val/error_v=1.110, val/error_h=0.441, val/loss_best=0.842, train/loss_epoch=0.0687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 82.97it/s]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 31.22it/s, v_num=40, train/loss_step=0.0677, val/loss=0.880, val/error_u=0.839, val/error_v=1.110, val/error_h=0.438, val/loss_best=0.842, train/loss_epoch=0.0687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.38it/s]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 28.81it/s, v_num=40, train/loss_step=0.0657, val/loss=0.882, val/error_u=0.838, val/error_v=1.120, val/error_h=0.434, val/loss_best=0.842, train/loss_epoch=0.0677]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.77it/s]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 31.91it/s, v_num=40, train/loss_step=0.0647, val/loss=0.883, val/error_u=0.836, val/error_v=1.130, val/error_h=0.430, val/loss_best=0.842, train/loss_epoch=0.0657]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 78.74it/s]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 32.33it/s, v_num=40, train/loss_step=0.0637, val/loss=0.884, val/error_u=0.837, val/error_v=1.130, val/error_h=0.428, val/loss_best=0.842, train/loss_epoch=0.0647]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 89.15it/s]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 30.04it/s, v_num=40, train/loss_step=0.0624, val/loss=0.887, val/error_u=0.843, val/error_v=1.130, val/error_h=0.427, val/loss_best=0.842, train/loss_epoch=0.0637]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.49it/s]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 32.14it/s, v_num=40, train/loss_step=0.0621, val/loss=0.891, val/error_u=0.849, val/error_v=1.130, val/error_h=0.428, val/loss_best=0.842, train/loss_epoch=0.0624]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.72it/s]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 30.40it/s, v_num=40, train/loss_step=0.0614, val/loss=0.896, val/error_u=0.852, val/error_v=1.130, val/error_h=0.428, val/loss_best=0.842, train/loss_epoch=0.0621]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 74.24it/s]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 28.88it/s, v_num=40, train/loss_step=0.0601, val/loss=0.900, val/error_u=0.854, val/error_v=1.140, val/error_h=0.427, val/loss_best=0.842, train/loss_epoch=0.0614]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.64it/s]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 28.09it/s, v_num=40, train/loss_step=0.0596, val/loss=0.903, val/error_u=0.854, val/error_v=1.140, val/error_h=0.425, val/loss_best=0.842, train/loss_epoch=0.0601]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 74.95it/s]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 27.35it/s, v_num=40, train/loss_step=0.059, val/loss=0.906, val/error_u=0.855, val/error_v=1.150, val/error_h=0.423, val/loss_best=0.842, train/loss_epoch=0.0596]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.10it/s]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 29.02it/s, v_num=40, train/loss_step=0.0581, val/loss=0.908, val/error_u=0.857, val/error_v=1.150, val/error_h=0.422, val/loss_best=0.842, train/loss_epoch=0.059]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.88it/s]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00, 28.15it/s, v_num=40, train/loss_step=0.0575, val/loss=0.909, val/error_u=0.859, val/error_v=1.150, val/error_h=0.421, val/loss_best=0.842, train/loss_epoch=0.0581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.67it/s]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00, 33.76it/s, v_num=40, train/loss_step=0.0567, val/loss=0.910, val/error_u=0.861, val/error_v=1.150, val/error_h=0.419, val/loss_best=0.842, train/loss_epoch=0.0575]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.51it/s]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00, 28.24it/s, v_num=40, train/loss_step=0.056, val/loss=0.910, val/error_u=0.860, val/error_v=1.150, val/error_h=0.418, val/loss_best=0.842, train/loss_epoch=0.0567]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.20it/s]
# Epoch 50: 100%|██████████| 1/1 [00:00<00:00, 26.88it/s, v_num=40, train/loss_step=0.0558, val/loss=0.910, val/error_u=0.860, val/error_v=1.150, val/error_h=0.417, val/loss_best=0.842, train/loss_epoch=0.056]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.08it/s]
# Epoch 51: 100%|██████████| 1/1 [00:00<00:00, 28.62it/s, v_num=40, train/loss_step=0.0551, val/loss=0.912, val/error_u=0.861, val/error_v=1.160, val/error_h=0.416, val/loss_best=0.842, train/loss_epoch=0.0558]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.13it/s]
# Epoch 52: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s, v_num=40, train/loss_step=0.0543, val/loss=0.914, val/error_u=0.864, val/error_v=1.160, val/error_h=0.416, val/loss_best=0.842, train/loss_epoch=0.0551]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.90it/s]
# Epoch 53: 100%|██████████| 1/1 [00:00<00:00, 30.99it/s, v_num=40, train/loss_step=0.054, val/loss=0.916, val/error_u=0.866, val/error_v=1.160, val/error_h=0.415, val/loss_best=0.842, train/loss_epoch=0.0543]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.12it/s]
# Epoch 54: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s, v_num=40, train/loss_step=0.0536, val/loss=0.919, val/error_u=0.867, val/error_v=1.160, val/error_h=0.414, val/loss_best=0.842, train/loss_epoch=0.054]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.36it/s]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00, 30.01it/s, v_num=40, train/loss_step=0.0528, val/loss=0.921, val/error_u=0.868, val/error_v=1.160, val/error_h=0.413, val/loss_best=0.842, train/loss_epoch=0.0536]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 76.97it/s]
# Epoch 56: 100%|██████████| 1/1 [00:00<00:00, 31.31it/s, v_num=40, train/loss_step=0.0525, val/loss=0.922, val/error_u=0.869, val/error_v=1.170, val/error_h=0.412, val/loss_best=0.842, train/loss_epoch=0.0528]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.96it/s]
# Epoch 57: 100%|██████████| 1/1 [00:00<00:00, 30.85it/s, v_num=40, train/loss_step=0.052, val/loss=0.924, val/error_u=0.871, val/error_v=1.170, val/error_h=0.412, val/loss_best=0.842, train/loss_epoch=0.0525]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.60it/s]
# Epoch 58: 100%|██████████| 1/1 [00:00<00:00, 29.90it/s, v_num=40, train/loss_step=0.0514, val/loss=0.925, val/error_u=0.873, val/error_v=1.170, val/error_h=0.411, val/loss_best=0.842, train/loss_epoch=0.052]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.79it/s]
# Epoch 59: 100%|██████████| 1/1 [00:00<00:00, 29.34it/s, v_num=40, train/loss_step=0.051, val/loss=0.927, val/error_u=0.875, val/error_v=1.170, val/error_h=0.409, val/loss_best=0.842, train/loss_epoch=0.0514]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 76.45it/s]
# Epoch 60: 100%|██████████| 1/1 [00:00<00:00, 29.35it/s, v_num=40, train/loss_step=0.0506, val/loss=0.928, val/error_u=0.875, val/error_v=1.170, val/error_h=0.408, val/loss_best=0.842, train/loss_epoch=0.051]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.57it/s]
# Epoch 61: 100%|██████████| 1/1 [00:00<00:00, 29.00it/s, v_num=40, train/loss_step=0.0502, val/loss=0.929, val/error_u=0.875, val/error_v=1.170, val/error_h=0.407, val/loss_best=0.842, train/loss_epoch=0.0506]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.00it/s]
# Epoch 62: 100%|██████████| 1/1 [00:00<00:00, 29.92it/s, v_num=40, train/loss_step=0.0498, val/loss=0.929, val/error_u=0.876, val/error_v=1.170, val/error_h=0.407, val/loss_best=0.842, train/loss_epoch=0.0502]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.45it/s]
# Epoch 63: 100%|██████████| 1/1 [00:00<00:00, 30.08it/s, v_num=40, train/loss_step=0.0493, val/loss=0.931, val/error_u=0.878, val/error_v=1.170, val/error_h=0.406, val/loss_best=0.842, train/loss_epoch=0.0498]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.05it/s]
# Epoch 64: 100%|██████████| 1/1 [00:00<00:00, 29.39it/s, v_num=40, train/loss_step=0.049, val/loss=0.933, val/error_u=0.880, val/error_v=1.170, val/error_h=0.405, val/loss_best=0.842, train/loss_epoch=0.0493]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.12it/s]
# Epoch 65: 100%|██████████| 1/1 [00:00<00:00, 29.93it/s, v_num=40, train/loss_step=0.0486, val/loss=0.934, val/error_u=0.881, val/error_v=1.170, val/error_h=0.404, val/loss_best=0.842, train/loss_epoch=0.049]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.45it/s]
# Epoch 66: 100%|██████████| 1/1 [00:00<00:00, 31.06it/s, v_num=40, train/loss_step=0.0482, val/loss=0.936, val/error_u=0.882, val/error_v=1.180, val/error_h=0.404, val/loss_best=0.842, train/loss_epoch=0.0486]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.12it/s]
# Epoch 67: 100%|██████████| 1/1 [00:00<00:00, 30.79it/s, v_num=40, train/loss_step=0.0479, val/loss=0.937, val/error_u=0.883, val/error_v=1.180, val/error_h=0.403, val/loss_best=0.842, train/loss_epoch=0.0482]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 80.30it/s]
# Epoch 68: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s, v_num=40, train/loss_step=0.0475, val/loss=0.939, val/error_u=0.885, val/error_v=1.180, val/error_h=0.402, val/loss_best=0.842, train/loss_epoch=0.0479]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.25it/s]
# Epoch 69: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s, v_num=40, train/loss_step=0.0472, val/loss=0.942, val/error_u=0.887, val/error_v=1.180, val/error_h=0.401, val/loss_best=0.842, train/loss_epoch=0.0475]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.41it/s]
# Epoch 70: 100%|██████████| 1/1 [00:00<00:00, 31.12it/s, v_num=40, train/loss_step=0.0468, val/loss=0.944, val/error_u=0.889, val/error_v=1.180, val/error_h=0.400, val/loss_best=0.842, train/loss_epoch=0.0472]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.69it/s]
# Epoch 71: 100%|██████████| 1/1 [00:00<00:00, 24.99it/s, v_num=40, train/loss_step=0.0465, val/loss=0.945, val/error_u=0.890, val/error_v=1.180, val/error_h=0.399, val/loss_best=0.842, train/loss_epoch=0.0468]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.68it/s]
# Epoch 72: 100%|██████████| 1/1 [00:00<00:00, 26.72it/s, v_num=40, train/loss_step=0.0462, val/loss=0.946, val/error_u=0.891, val/error_v=1.180, val/error_h=0.398, val/loss_best=0.842, train/loss_epoch=0.0465]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.22it/s]
# Epoch 73: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s, v_num=40, train/loss_step=0.0459, val/loss=0.947, val/error_u=0.892, val/error_v=1.190, val/error_h=0.398, val/loss_best=0.842, train/loss_epoch=0.0462]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.67it/s]
# Epoch 74: 100%|██████████| 1/1 [00:00<00:00, 29.83it/s, v_num=40, train/loss_step=0.0456, val/loss=0.949, val/error_u=0.894, val/error_v=1.190, val/error_h=0.397, val/loss_best=0.842, train/loss_epoch=0.0459]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.99it/s]
# Epoch 75: 100%|██████████| 1/1 [00:00<00:00, 30.36it/s, v_num=40, train/loss_step=0.0453, val/loss=0.952, val/error_u=0.896, val/error_v=1.190, val/error_h=0.396, val/loss_best=0.842, train/loss_epoch=0.0456]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.84it/s]
# Epoch 76: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s, v_num=40, train/loss_step=0.0449, val/loss=0.953, val/error_u=0.897, val/error_v=1.190, val/error_h=0.396, val/loss_best=0.842, train/loss_epoch=0.0453]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.20it/s]
# Epoch 77: 100%|██████████| 1/1 [00:00<00:00, 28.53it/s, v_num=40, train/loss_step=0.0447, val/loss=0.955, val/error_u=0.898, val/error_v=1.190, val/error_h=0.395, val/loss_best=0.842, train/loss_epoch=0.0449]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.02it/s]
# Epoch 78: 100%|██████████| 1/1 [00:00<00:00, 30.08it/s, v_num=40, train/loss_step=0.0443, val/loss=0.957, val/error_u=0.900, val/error_v=1.190, val/error_h=0.394, val/loss_best=0.842, train/loss_epoch=0.0447]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.74it/s]
# Epoch 79: 100%|██████████| 1/1 [00:00<00:00, 28.66it/s, v_num=40, train/loss_step=0.0441, val/loss=0.960, val/error_u=0.902, val/error_v=1.190, val/error_h=0.393, val/loss_best=0.842, train/loss_epoch=0.0443]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 78.44it/s]
# Epoch 80: 100%|██████████| 1/1 [00:00<00:00, 26.10it/s, v_num=40, train/loss_step=0.0438, val/loss=0.961, val/error_u=0.903, val/error_v=1.190, val/error_h=0.393, val/loss_best=0.842, train/loss_epoch=0.0441]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.88it/s]
# Epoch 81: 100%|██████████| 1/1 [00:00<00:00, 30.93it/s, v_num=40, train/loss_step=0.0435, val/loss=0.963, val/error_u=0.904, val/error_v=1.200, val/error_h=0.392, val/loss_best=0.842, train/loss_epoch=0.0438]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.17it/s]
# Epoch 82: 100%|██████████| 1/1 [00:00<00:00, 28.16it/s, v_num=40, train/loss_step=0.0432, val/loss=0.964, val/error_u=0.906, val/error_v=1.200, val/error_h=0.392, val/loss_best=0.842, train/loss_epoch=0.0435]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.58it/s]
# Epoch 83: 100%|██████████| 1/1 [00:00<00:00, 30.08it/s, v_num=40, train/loss_step=0.043, val/loss=0.966, val/error_u=0.908, val/error_v=1.200, val/error_h=0.391, val/loss_best=0.842, train/loss_epoch=0.0432]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.20it/s]
# Epoch 84: 100%|██████████| 1/1 [00:00<00:00, 31.32it/s, v_num=40, train/loss_step=0.0427, val/loss=0.968, val/error_u=0.909, val/error_v=1.200, val/error_h=0.390, val/loss_best=0.842, train/loss_epoch=0.043]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.88it/s]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 27.40it/s, v_num=40, train/loss_step=0.0424, val/loss=0.969, val/error_u=0.910, val/error_v=1.200, val/error_h=0.390, val/loss_best=0.842, train/loss_epoch=0.0427]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.73it/s]
# Epoch 86: 100%|██████████| 1/1 [00:00<00:00, 27.90it/s, v_num=40, train/loss_step=0.0422, val/loss=0.971, val/error_u=0.912, val/error_v=1.200, val/error_h=0.389, val/loss_best=0.842, train/loss_epoch=0.0424]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 86.61it/s]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 28.23it/s, v_num=40, train/loss_step=0.0419, val/loss=0.973, val/error_u=0.914, val/error_v=1.200, val/error_h=0.388, val/loss_best=0.842, train/loss_epoch=0.0422]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.14it/s]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 28.87it/s, v_num=40, train/loss_step=0.0417, val/loss=0.975, val/error_u=0.916, val/error_v=1.200, val/error_h=0.388, val/loss_best=0.842, train/loss_epoch=0.0419]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.45it/s]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 29.07it/s, v_num=40, train/loss_step=0.0414, val/loss=0.976, val/error_u=0.917, val/error_v=1.200, val/error_h=0.387, val/loss_best=0.842, train/loss_epoch=0.0417]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.85it/s]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 29.17it/s, v_num=40, train/loss_step=0.0412, val/loss=0.978, val/error_u=0.918, val/error_v=1.200, val/error_h=0.387, val/loss_best=0.842, train/loss_epoch=0.0414]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.72it/s]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s, v_num=40, train/loss_step=0.0409, val/loss=0.980, val/error_u=0.920, val/error_v=1.210, val/error_h=0.386, val/loss_best=0.842, train/loss_epoch=0.0412]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.73it/s]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 27.87it/s, v_num=40, train/loss_step=0.0407, val/loss=0.982, val/error_u=0.921, val/error_v=1.210, val/error_h=0.385, val/loss_best=0.842, train/loss_epoch=0.0409]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.38it/s]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 28.05it/s, v_num=40, train/loss_step=0.0404, val/loss=0.984, val/error_u=0.923, val/error_v=1.210, val/error_h=0.385, val/loss_best=0.842, train/loss_epoch=0.0407]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.86it/s]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 31.16it/s, v_num=40, train/loss_step=0.0402, val/loss=0.985, val/error_u=0.924, val/error_v=1.210, val/error_h=0.384, val/loss_best=0.842, train/loss_epoch=0.0404]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.68it/s]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 29.96it/s, v_num=40, train/loss_step=0.0399, val/loss=0.987, val/error_u=0.926, val/error_v=1.210, val/error_h=0.384, val/loss_best=0.842, train/loss_epoch=0.0402]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.91it/s]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 30.91it/s, v_num=40, train/loss_step=0.0397, val/loss=0.989, val/error_u=0.928, val/error_v=1.210, val/error_h=0.383, val/loss_best=0.842, train/loss_epoch=0.0399]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.70it/s]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 28.75it/s, v_num=40, train/loss_step=0.0395, val/loss=0.991, val/error_u=0.930, val/error_v=1.210, val/error_h=0.383, val/loss_best=0.842, train/loss_epoch=0.0397]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.17it/s]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 31.00it/s, v_num=40, train/loss_step=0.0393, val/loss=0.993, val/error_u=0.931, val/error_v=1.210, val/error_h=0.382, val/loss_best=0.842, train/loss_epoch=0.0395]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.75it/s]
# ...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.47it/s]
# Epoch 965: 100%|██████████| 1/1 [00:00<00:00, 33.57it/s, v_num=40, train/loss_step=0.0148, val/loss=1.080, val/error_u=1.100, val/error_v=1.170, val/error_h=0.274, val/loss_best=0.842, train/loss_epoch=0.0176]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 90.53it/s]
# Epoch 966: 100%|██████████| 1/1 [00:00<00:00, 31.55it/s, v_num=40, train/loss_step=0.0144, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.0148]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 81.39it/s]
# Epoch 967: 100%|██████████| 1/1 [00:00<00:00, 31.54it/s, v_num=40, train/loss_step=0.0144, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.272, val/loss_best=0.842, train/loss_epoch=0.0144]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 81.71it/s]
# Epoch 968: 100%|██████████| 1/1 [00:00<00:00, 21.06it/s, v_num=40, train/loss_step=0.014, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.275, val/loss_best=0.842, train/loss_epoch=0.0144]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 85.45it/s]
# Epoch 969: 100%|██████████| 1/1 [00:00<00:00, 31.20it/s, v_num=40, train/loss_step=0.014, val/loss=1.090, val/error_u=1.110, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.014]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 75.78it/s]
# Epoch 970: 100%|██████████| 1/1 [00:00<00:00, 33.29it/s, v_num=40, train/loss_step=0.012, val/loss=1.090, val/error_u=1.100, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.014]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.88it/s]
# Epoch 971: 100%|██████████| 1/1 [00:00<00:00, 27.19it/s, v_num=40, train/loss_step=0.0133, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.274, val/loss_best=0.842, train/loss_epoch=0.012]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.37it/s]
# Epoch 972: 100%|██████████| 1/1 [00:00<00:00, 27.30it/s, v_num=40, train/loss_step=0.0128, val/loss=1.090, val/error_u=1.100, val/error_v=1.180, val/error_h=0.274, val/loss_best=0.842, train/loss_epoch=0.0133]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 97.47it/s]
# Epoch 973: 100%|██████████| 1/1 [00:00<00:00, 32.84it/s, v_num=40, train/loss_step=0.0118, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.274, val/loss_best=0.842, train/loss_epoch=0.0128]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 90.43it/s]
# Epoch 974: 100%|██████████| 1/1 [00:00<00:00, 31.82it/s, v_num=40, train/loss_step=0.0121, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.0118]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.75it/s]
# Epoch 975: 100%|██████████| 1/1 [00:00<00:00, 28.67it/s, v_num=40, train/loss_step=0.0114, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.0121]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 79.99it/s]
# Epoch 976: 100%|██████████| 1/1 [00:00<00:00, 28.87it/s, v_num=40, train/loss_step=0.012, val/loss=1.080, val/error_u=1.100, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.0114]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 86.92it/s]
# Epoch 977: 100%|██████████| 1/1 [00:00<00:00, 33.08it/s, v_num=40, train/loss_step=0.011, val/loss=1.080, val/error_u=1.090, val/error_v=1.180, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.012]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 83.86it/s]
# Epoch 978: 100%|██████████| 1/1 [00:00<00:00, 30.22it/s, v_num=40, train/loss_step=0.0106, val/loss=1.070, val/error_u=1.090, val/error_v=1.180, val/error_h=0.272, val/loss_best=0.842, train/loss_epoch=0.011]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.04it/s]
# Epoch 979: 100%|██████████| 1/1 [00:00<00:00, 22.17it/s, v_num=40, train/loss_step=0.0113, val/loss=1.070, val/error_u=1.090, val/error_v=1.180, val/error_h=0.271, val/loss_best=0.842, train/loss_epoch=0.0106]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 97.83it/s]
# Epoch 980: 100%|██████████| 1/1 [00:00<00:00, 31.88it/s, v_num=40, train/loss_step=0.0106, val/loss=1.070, val/error_u=1.090, val/error_v=1.180, val/error_h=0.271, val/loss_best=0.842, train/loss_epoch=0.0113]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 91.71it/s]
# Epoch 981: 100%|██████████| 1/1 [00:00<00:00, 23.10it/s, v_num=40, train/loss_step=0.0105, val/loss=1.070, val/error_u=1.090, val/error_v=1.180, val/error_h=0.271, val/loss_best=0.842, train/loss_epoch=0.0106]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 46.76it/s]
# Epoch 982: 100%|██████████| 1/1 [00:00<00:00, 18.54it/s, v_num=40, train/loss_step=0.0102, val/loss=1.060, val/error_u=1.090, val/error_v=1.180, val/error_h=0.271, val/loss_best=0.842, train/loss_epoch=0.0105]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 42.80it/s]
# Epoch 983: 100%|██████████| 1/1 [00:00<00:00, 19.00it/s, v_num=40, train/loss_step=0.0104, val/loss=1.060, val/error_u=1.090, val/error_v=1.180, val/error_h=0.269, val/loss_best=0.842, train/loss_epoch=0.0102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 40.62it/s]
# Epoch 984: 100%|██████████| 1/1 [00:00<00:00, 15.70it/s, v_num=40, train/loss_step=0.0102, val/loss=1.060, val/error_u=1.080, val/error_v=1.180, val/error_h=0.269, val/loss_best=0.842, train/loss_epoch=0.0104]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 38.75it/s]
# Epoch 985: 100%|██████████| 1/1 [00:00<00:00, 25.45it/s, v_num=40, train/loss_step=0.00995, val/loss=1.060, val/error_u=1.080, val/error_v=1.170, val/error_h=0.269, val/loss_best=0.842, train/loss_epoch=0.0102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 80.21it/s]
# Epoch 986: 100%|██████████| 1/1 [00:00<00:00, 18.96it/s, v_num=40, train/loss_step=0.00994, val/loss=1.050, val/error_u=1.080, val/error_v=1.170, val/error_h=0.268, val/loss_best=0.842, train/loss_epoch=0.00995]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.36it/s]
# Epoch 987: 100%|██████████| 1/1 [00:00<00:00, 31.75it/s, v_num=40, train/loss_step=0.00993, val/loss=1.050, val/error_u=1.080, val/error_v=1.170, val/error_h=0.267, val/loss_best=0.842, train/loss_epoch=0.00994]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 98.03it/s]
# Epoch 988: 100%|██████████| 1/1 [00:00<00:00, 29.51it/s, v_num=40, train/loss_step=0.010, val/loss=1.050, val/error_u=1.070, val/error_v=1.170, val/error_h=0.267, val/loss_best=0.842, train/loss_epoch=0.00993]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 92.11it/s]
# Epoch 989: 100%|██████████| 1/1 [00:00<00:00, 31.24it/s, v_num=40, train/loss_step=0.0101, val/loss=1.040, val/error_u=1.070, val/error_v=1.170, val/error_h=0.266, val/loss_best=0.842, train/loss_epoch=0.010]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.41it/s]
# Epoch 990: 100%|██████████| 1/1 [00:00<00:00, 27.32it/s, v_num=40, train/loss_step=0.0105, val/loss=1.040, val/error_u=1.070, val/error_v=1.170, val/error_h=0.266, val/loss_best=0.842, train/loss_epoch=0.0101]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 90.54it/s]
# Epoch 991: 100%|██████████| 1/1 [00:00<00:00, 29.54it/s, v_num=40, train/loss_step=0.0115, val/loss=1.040, val/error_u=1.070, val/error_v=1.170, val/error_h=0.264, val/loss_best=0.842, train/loss_epoch=0.0105]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 89.29it/s]
# Epoch 992: 100%|██████████| 1/1 [00:00<00:00, 34.08it/s, v_num=40, train/loss_step=0.0143, val/loss=1.030, val/error_u=1.060, val/error_v=1.170, val/error_h=0.266, val/loss_best=0.842, train/loss_epoch=0.0115]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 81.18it/s]
# Epoch 993: 100%|██████████| 1/1 [00:00<00:00, 32.63it/s, v_num=40, train/loss_step=0.0197, val/loss=1.040, val/error_u=1.070, val/error_v=1.170, val/error_h=0.263, val/loss_best=0.842, train/loss_epoch=0.0143]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.32it/s]
# Epoch 994: 100%|██████████| 1/1 [00:00<00:00, 23.29it/s, v_num=40, train/loss_step=0.0312, val/loss=1.020, val/error_u=1.050, val/error_v=1.170, val/error_h=0.266, val/loss_best=0.842, train/loss_epoch=0.0197]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.69it/s]
# Epoch 995: 100%|██████████| 1/1 [00:00<00:00, 32.68it/s, v_num=40, train/loss_step=0.0452, val/loss=1.040, val/error_u=1.080, val/error_v=1.160, val/error_h=0.263, val/loss_best=0.842, train/loss_epoch=0.0312]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 80.68it/s]
# Epoch 996: 100%|██████████| 1/1 [00:00<00:00, 34.69it/s, v_num=40, train/loss_step=0.0587, val/loss=1.020, val/error_u=1.050, val/error_v=1.180, val/error_h=0.269, val/loss_best=0.842, train/loss_epoch=0.0452]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 88.57it/s]
# Epoch 997: 100%|██████████| 1/1 [00:00<00:00, 24.61it/s, v_num=40, train/loss_step=0.0414, val/loss=1.060, val/error_u=1.080, val/error_v=1.170, val/error_h=0.265, val/loss_best=0.842, train/loss_epoch=0.0587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 84.33it/s]
# Epoch 998: 100%|██████████| 1/1 [00:00<00:00, 27.93it/s, v_num=40, train/loss_step=0.0196, val/loss=1.040, val/error_u=1.070, val/error_v=1.170, val/error_h=0.273, val/loss_best=0.842, train/loss_epoch=0.0414]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 98.66it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 34.09it/s, v_num=40, train/loss_step=0.0195, val/loss=1.050, val/error_u=1.070, val/error_v=1.170, val/error_h=0.272, val/loss_best=0.842, train/loss_epoch=0.0196]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 85.75it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 18.04it/s, v_num=40, train/loss_step=0.0195, val/loss=1.060, val/error_u=1.090, val/error_v=1.170, val/error_h=0.272, val/loss_best=0.842, train/loss_epoch=0.0195]
# `Trainer.fit` stopped: `max_epochs=1000` reached.
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 15.51it/s, v_num=40, train/loss_step=0.0195, val/loss=1.060, val/error_u=1.090, val/error_v=1.170, val/error_h=0.272, val/loss_best=0.842, train/loss_epoch=0.0195]
# CPU times: total: 1min 24s
# Wall time: 1min 25s

# %% [markdown]
# ### Validation

# %%
trainer.validate(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.96it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        val/error_h        │    0.27209174633026123    │
# │        val/error_u        │     1.087910532951355     │
# │        val/error_v        │     1.168275237083435     │
# │         val/loss          │    1.0608665943145752     │
# │       val/loss_best       │    0.8415444493293762     │
# └───────────────────────────┴───────────────────────────┘
# [{'val/loss': 1.0608665943145752,
#   'val/error_u': 1.087910532951355,
#   'val/error_v': 1.168275237083435,
#   'val/error_h': 0.27209174633026123,
#   'val/loss_best': 0.8415444493293762}]

# %% [markdown]
# ### Plotting
#
# For plotting, we need predict the results, and then, we should concatenate the results.

# %%
preds_list = trainer.predict(model=model, datamodule=datamodule)
preds_dict = pinnstorch.utils.fix_predictions(preds_list)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.62it/s]

# %%
pinnstorch.utils.plot_schrodinger(mesh=mesh,
                                  preds=preds_dict,
                                  train_datasets=train_datasets,
                                  val_dataset=val_dataset,
                                  file_name='out')
