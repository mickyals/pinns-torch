# %% [markdown]
# ## Tutorial - 0: Continuous Forward Schrodinger
#
# Welcome to our first tutorial on Physics-Informed Neural Networks (PINNs) using `PyTorch Lightning` and our new package, **`pinnstorch`**! This guide aims to introduce you to the integration of deep learning and scientific computing via PINNs, which embed physical laws into neural network training.
#
# #### Overview:
#
# - **Mesh Generation and Sampling:** Understanding how to create and use meshes for training PINNs, crucial for defining the domain of our problem.
# - **Neural Network Model with PINNs:** How to build and structure a neural network for physical law integration.
# - **Physical Laws in Neural Networks:** Detailing the implementation of differential equations within the network using `pde_fn` and `output_fn`.
# - **Training and Validation:** Utilizing PyTorch Lightning’s Trainer to train our model, including defining the training data, initial conditions, and handling boundary conditions.
# - **Results Visualization:** Saving and analyzing the outcomes of your PINN models.

# %% [markdown]
# #### Install Libraries

# %%
# !pip install pinnstorch
# !pip install lightning
# Out:
# Requirement already satisfied: pinnstorch in c:\users\micke\onedrive - university of toronto\pinns-torch (0.1.2)
# Requirement already satisfied: hydra-core in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.3.2)
# Requirement already satisfied: scipy in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.13.1)
# Requirement already satisfied: pyDOE in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (0.3.8)
# Requirement already satisfied: matplotlib in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (3.10.0)
# Requirement already satisfied: rootutils in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.0.7)
# Requirement already satisfied: tqdm in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (4.66.5)
# Requirement already satisfied: rich in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (13.7.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (4.9.3)
# Requirement already satisfied: packaging in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.15.1)
# Requirement already satisfied: python-dotenv>=0.20.0 in c:\users\micke\anaconda3\lib\site-packages (from rootutils->pinnstorch) (0.21.0)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm->pinnstorch) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\micke\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->pinnstorch) (0.1.0)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\micke\anaconda3\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core->pinnstorch) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\micke\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pinnstorch) (1.16.0)
# Requirement already satisfied: lightning in c:\users\micke\anaconda3\lib\site-packages (2.5.5)
# Requirement already satisfied: PyYAML<8.0,>5.4 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (0.11.9)
# Requirement already satisfied: packaging<27.0,>=20.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.3.1)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (1.4.0.post0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.66.5)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.11.0)
# Requirement already satisfied: pytorch-lightning in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (3.10.5)
# Requirement already satisfied: setuptools in c:\users\micke\anaconda3\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: filelock in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.13.1)
# Requirement already satisfied: sympy in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.2)
# Requirement already satisfied: networkx in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.4)
# Requirement already satisfied: numpy>1.20.0 in c:\users\micke\anaconda3\lib\site-packages (from torchmetrics<3.0,>0.7.0->lightning) (1.26.4)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\micke\anaconda3\lib\site-packages (from sympy->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (3.7)

# %% [markdown]
# #### Import Libraries

# %%
from typing import Dict

import torch
import numpy as np
import lightning.pytorch as pl

import pinnstorch
from pinnstorch.models.net.activations import SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

# %% [markdown]
# ### Define Mesh
#
# Physics-Informed Neural Networks (PINNs) require a discretized domain (mesh) over which the physical equations are solved. In `pinnstorch`, there are primarily two approaches to define this mesh:
#
#
# - **Defining Time and Spatial Domains Separately:** Here, we use `pinnstorch.data.TimeDomain` and `pinnstorch.data.Interval` for creating 1-D spatial domains. These domains are then used to define a `pinnstorch.data.Mesh`.
#
# - **Defining Point Clouds:** This method involves directly utilizing spatio-temporal data (e.g., from experiments or other simulations) to create a mesh using `pinnstorch.data.PointCloud`.
#
# Both approaches should ideally yield the same results.

# %% [markdown]
# #### Option 1: Defining Mesh with Separate Time and Spatial Domains
#
# We start by defining a function to read and preprocess the solution data from a file. The output should be a dictionary.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in Mesh class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")
    exact = data["uu"] # complex number shape N x T
    exact_u = np.real(exact) # N x T # real part
    exact_v = np.imag(exact) # N x T # imaginary part
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T # absolute value ----> ||X|| = sqrt(x^2 + y^2)
    return {"u": exact_u, "v": exact_v, "h": exact_h} # return dict of solutions {u:real, v:imag, h:absolute value}

# %% [markdown]
# Now, define the time and spatial domains for mesh generation. The choice of these parameters depends on the specific problem being solved and should be set accordingly.

# %%
time_domain = pinnstorch.data.TimeDomain(t_interval=[0, 1.57079633], t_points = 201)
spatial_domain = pinnstorch.data.Interval(x_interval= [-5, 4.9609375], shape = [256, 1])

# %% [markdown]
# The mesh is then defined using the time and spatial domains along with the read_data_fn function.

# %%
mesh = pinnstorch.data.Mesh(root_dir='../data',
                            read_data_fn=read_data_fn,
                            spatial_domain = spatial_domain,
                            time_domain = time_domain)

# %% [markdown]
# #### Option 2: Using Point Clouds
#
# For scenarios where the spatial and temporal data along with solutions are directly available (e.g., from experimental measurements), we can create a mesh using `pinnstorch.data.PointCloud`.
#
# **Note:** It's crucial to format the spatial and temporal domain dimensions correctly. Specifically:
#
# - **Spatial Domain:** Each axis should be structured in the shape of $(N \times 1)$, where $N$ represents the number of spatial points.
# - **Time Domain:** This should be formatted as $(T \times 1)$, where $T$ indicates the number of time steps.
# - **Solution Data:** Each solution variable (e.g., temperature, velocity) should be in the shape of $(N \times T)$, aligning with the spatial and temporal points.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in PointCloud class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")

    x = data["x"].T  # N x 1
    t = data["tt"].T  # T x 1
    
    exact = data["uu"]
    exact_u = np.real(exact) # N x T
    exact_v = np.imag(exact) # N x T
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T
    
    return pinnstorch.data.PointCloudData(
            spatial=[x], time=[t], solution={"u": exact_u, "v": exact_v, "h": exact_h}
    )

# %% [markdown]
# Now, mesh can be initalize with using the function and the directory to the folder of data.

# %%
mesh = pinnstorch.data.PointCloud(root_dir='./data',
                                  read_data_fn=read_data_fn)

# %% [markdown]
# ### Define Train datasets

# %% [markdown]
# For solving Schrodinger PDE, we have:
# - Initial condition
# - Periodic boundary condition
# - Collection points for the PDE.

# %% [markdown]
# #### Initial Condition
#
# Let's start with initial condition of the Schrodinger.
# $$ u(0, x) = 2 \text{sech}(x) $$
# $$ v(0, x) = 0 $$
#
# For defining initial condition, again we have two options.
#
# - **Sample from the data.**
# - **Defining a function for calculating initial condition.**

# %% [markdown]
# ##### Set number of samples

# %%
N0 = 50

# %% [markdown]
# ##### Option 1: Sample from the data

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        solution = ['u', 'v'])

# %% [markdown]
# ##### Option 2: Defining a function for calculating initial condition

# %% [markdown]
# The input of `initial_fun` should be the same as spatial domain of the problem.

# %%
def initial_fun(x):
    return {'u': 2*1/np.cosh(x), 'v': np.zeros_like(x)}

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        initial_fun = initial_fun,
                                        solution = ['u', 'v'])

# %% [markdown]
# The `solution` attribute in `pinnstorch.data.InitialCondition` specifies the solutions (`u` and `v` in our case) to be sampled for initial conditions.

# %% [markdown]
# #### Periodic Boundary Condition

# %% [markdown]
# The `pinnstorch.data.PeriodicBoundaryCondition` is used to sample periodic points from the upper and lower bounds of the spatial domain (mesh). The `derivative_order` parameter specifies the order of the derivative to be matched at these boundaries. In our case, for the Schrödinger equation, both the function and its first spatial derivative should match at the boundaries, hence `derivative_order = 1`.
#
#
# $$ u(t,-5) = u(t, 5), $$
# $$ v(t,-5) = v(t, 5), $$
# $$ u_x(t,-5) = u_x(t, 5),$$
# $$ v_x(t,-5) = v_x(t, 5) $$

# %%
N_b = 50
pe_b = pinnstorch.data.PeriodicBoundaryCondition(mesh = mesh,
                                                 num_sample = 50,
                                                 derivative_order = 1,
                                                 solution = ['u', 'v'])

# %% [markdown]
# #### Mesh Sampler for collection points and solutions
#
# In our problem, the partial differential equations (PDEs) governing the dynamics are given by:
#
# $$ f_u := u_t + 0.5v_{xx} + v(u^2 +v^2),$$
# $$ f_v := v_t + 0.5u_{xx} + u(u^2 +v^2) $$
#
# To find the solutions to these PDEs using a neural network, we must sample points from the domain at which the network will be trained to satisfy these equations. This sampling process is crucial for training our PINN. We utilize the `pinnstorch.data.MeshSampler` for this purpose, specifying the following:
#
# - **Number of Sample Points (N_f):** We choose to sample 20,000 points from the domain. This number is a balance between computational efficiency and the need for a sufficiently dense sampling to capture the dynamics of the PDEs.
# - **Mesh (mesh):** This parameter defines the spatial-temporal domain from which the points will be sampled.
# - **Collection Points:** We define `['f_u', 'f_v']` as the targets for our collection points. These are not direct outputs from the neural network but are derived from the network outputs and their derivatives (We will define `pde_fn` function later). The PINN will be trained such that these expressions tend towards zero, aligning with the PDE constraints.
#
# Here's the code to implement this sampler:

# %%
N_f = 20000
me_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                   num_sample = N_f,
                                   collection_points = ['f_v', 'f_u'])

# %% [markdown]
# ### Define Validation dataset
#
# For validation, we sample all points from the mesh to evaluate our model comprehensively. Model will be validated for solutions of `u`, `v`, and `h`.
#
# **Note:** If `num_sample` is not specified, the sampler will use the entire mesh for data sampling.

# %%
val_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                    solution = ['u', 'v', 'h'])

# %% [markdown]
# ### Define Neural Networks
#
# Here, we try to define a neural network for solving the problem. For defining a neural network, we should set number of layers and the name of the outputs. Also, domain bounds should be defined. The `lb` and `ub` parameters represent the lower and upper bounds of the spatial-temporal domain, helping in normalizing inputs to the network. Therefore, the inputs of this network are `x` and `t`, and the outputs of this network are `u` and `v`.

# %%
# SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

net = pinnstorch.models.FCN(layers = [2, 200, 200, 200, 200, 200, 2],
                            output_names = ['u', 'v'],
                            lb=mesh.lb,
                            ub=mesh.ub,
                            activation=lambda: WireActivation(omega_0=20, sigma_0=10))

# %% [markdown]
# ### Define `pde_fn` and `output_fn` functions
#
# Now, we define `pde_fn` and `output_fn`.
# - **`output_fn`:** is applied to the network's output, adding any necessary post-processing computations. For example, in our case, `h(x,t) = u(x,t)**2 + v(x,t)**2`, thus, we define this equation in `output_fn`.
# - **`pde_fn`:** formulates the PDE constraints, which will be used by the `MeshSampler` to compute the loss at the collection points.

# %% [markdown]
# #### `output_fn` function
#
# **Note:** `output_fn` should always have these inputs:
# - **Outputs:** It is output of the network. In our case, this dictionary should have two output: `u` and `v`.
# - **Spatial domains:** These are the spatial domain variables. In our case, because our problem has 1-D spatial domain, the input just have `x`. For example, if we had 2-D space, we need another input for that dimention. For example, the inputs from `(outputs, x, t)` will be changed to `(outputs, x, y, t)`.
# - **Time domin:** The last input of `output_fn` function always should be time.

# %%
def output_fn(outputs: Dict[str, torch.Tensor],
              x: torch.Tensor,
              t: torch.Tensor):
    """Define `output_fn` function that will be applied to outputs of net."""

    outputs["h"] = torch.sqrt(outputs["u"] ** 2 + outputs["v"] ** 2)

    return outputs

# %% [markdown]
# #### `pde_fn` function
#
# The inputs are similar to `output_fn`. Only if we have extra variables for training (i.g. in inverse problems), we should add input at the end of inputs. For example, `(outputs, x, t)` will be `(outputs, x, t, extra_variable)`. `extra_variable` is always a dictionary.

# %%
def pde_fn(outputs: Dict[str, torch.Tensor],
           x: torch.Tensor,
           t: torch.Tensor):   
    """Define the partial differential equations (PDEs)."""
    u_x, u_t = pinnstorch.utils.gradient(outputs["u"], [x, t])
    v_x, v_t = pinnstorch.utils.gradient(outputs["v"], [x, t])

    u_xx = pinnstorch.utils.gradient(u_x, x)[0]
    v_xx = pinnstorch.utils.gradient(v_x, x)[0]

    outputs["f_u"] = u_t + 0.5 * v_xx + (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["v"]
    outputs["f_v"] = v_t - 0.5 * u_xx - (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["u"]

    return outputs

# %% [markdown]
# ### Define PINNDataModule and PINNModule
#
# To integrate with Lightning, we utilize two specialized modules:
#
# - `PINNDataModule` (inherited from `LightningDataModule`) manages data.
# - `PINNModule` (derived from `LightningModule`) handles the model, compilation, and various enhancements like AMP.

# %% [markdown]
# #### Define `PINNDataModule`
# Here, we define collection points, initial condition, and preiodic boundary condition as training datasets, and also, we set validation set. `PINNDataModule` is used for defining training, validation, prediction, and test datasets.

# %%
train_datasets = [me_s, in_c, pe_b]
val_dataset = val_s
datamodule = pinnstorch.data.PINNDataModule(train_datasets = [me_s, in_c, pe_b],
                                            val_dataset = val_dataset,
                                            pred_dataset = val_s)

# %% [markdown]
# #### Define `PINNModule`
#
# `PINNModule` handle several things. Here, we will explore the inputs of this class:
# - **net:**  The neural network.
# - **pde_fn:** The function representing the PDE to solve.
# - **optimizer:**  (Optional) The optimizer for training. The default is Adam
# - **loss_fn:** (Optional) The loss function to use, either "sse" or "mse". The default is "sse".
# - **scheduler:** (Optional) Learning rate scheduler. The default is None.
# - **scaler:** (Optional) Gradient scaler for AMP. The default is `torch.cuda.amp.GradScaler`.
# - **extra_variables:** (Optional) Extra variables in inverse problems. The default is None.
# - **output_fn:** (Optional) function to process the model's output. The default is None.
# - **runge_kutta:** (Optional) Runge-Kutta method for solving PDEs in discrete mode. The default is None.
# - **cudagraph_compile:** Flag to enable CUDA Graph compilation. It works only with a single GPU. The default is True.
# - **jit_compile:** (Optional) Flag to enable JIT compilation. The default is True.
# - **amp:** (Optional) Flag to enable Automatic Mixed Precision (AMP). The default is False.
# - **inline:** (Optional) Flag to enable inline mode in JIT compilation. The default is False.
#
# In this example, we initalize `PINNModule` with defined variables. We set Adam optimizer and try to compile the model with CUDA Graph. The loss function here is Mean Square Error (MSE).

# %%
model = pinnstorch.models.PINNModule(net = net,
                                     pde_fn = pde_fn,
                                     output_fn = output_fn,
                                     loss_fn = 'mse')

# %% [markdown]
# ### Setting Up the Trainer
#
# For training our model, we configure a trainer in PyTorch Lightning. Currently, our setup uses a single GPU, as models compiled with CUDA Graph don't support multiple GPUs yet. For a comprehensive understanding of the trainer's options and functionalities, refer to the [official documentation](https://lightning.ai/docs/pytorch/stable/api/lightning.pytorch.trainer.trainer.Trainer.html). For example, arguments that you can set are:
# - **accelerator:**  Supports passing different accelerator types such as `cpu`, `gpu`, `tpu`, `ipu`, `hpu`, `mps`, and `auto`.
# - **devices:** The devices to use. Can be set to a positive number (int or str), a sequence of device indices (list or str), the value -1 to indicate all available devices should be used, or "auto" for automatic selection based on the chosen accelerator. Default: "auto".
# - **max_epochs:** Stop training once this number of epochs is reached.
# - **max_steps:** Stop training after this number of steps.
# - ...
#
# In our example, we configure the trainer for CPU use, specifying one device:

# %%
trainer = pl.Trainer(accelerator='gpu', devices=1, max_epochs = 1000)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# ### Training

# %%
# %%time
trainer.fit(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type       | Params | Mode
# -----------------------------------------------------
# 0 | net           | FCN        | 161 K  | train
# 1 | train_loss    | MeanMetric | 0      | train
# 2 | val_loss      | MeanMetric | 0      | train
# 3 | val_error     | MeanMetric | 0      | train
# 4 | test_loss     | MeanMetric | 0      | train
# 5 | test_error    | MeanMetric | 0      | train
# 6 | val_loss_best | MinMetric  | 0      | train
# -----------------------------------------------------
# 161 K     Trainable params
# 0         Non-trainable params
# 161 K     Total params
# 0.647     Total estimated model params size (MB)
# 19        Modules in train mode
# 0         Modules in eval mode
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  0.86it/s, v_num=22, train/loss_step=158.0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.21it/s]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  3.10it/s, v_num=22, train/loss_step=1.260, val/loss=1.600, val/error_u=1.240, val/error_v=1.100, val/error_h=0.760, val/loss_best=1.600, train/loss_epoch=158.0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.62it/s]
# Epoch 2: 100%|██████████| 1/1 [00:02<00:00,  0.36it/s, v_num=22, train/loss_step=10.10, val/loss=3.480, val/error_u=1.030, val/error_v=2.450, val/error_h=1.190, val/loss_best=1.600, train/loss_epoch=1.260]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 44.18it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  8.09it/s, v_num=22, train/loss_step=13.30, val/loss=3.670, val/error_u=0.886, val/error_v=2.580, val/error_h=1.260, val/loss_best=1.600, train/loss_epoch=10.10]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 42.28it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 14.38it/s, v_num=22, train/loss_step=4.200, val/loss=2.370, val/error_u=0.853, val/error_v=1.990, val/error_h=1.000, val/loss_best=1.600, train/loss_epoch=13.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.65it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 15.15it/s, v_num=22, train/loss_step=1.280, val/loss=1.510, val/error_u=0.861, val/error_v=1.410, val/error_h=0.818, val/loss_best=1.510, train/loss_epoch=4.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.27it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 16.24it/s, v_num=22, train/loss_step=0.619, val/loss=1.200, val/error_u=0.875, val/error_v=1.080, val/error_h=0.764, val/loss_best=1.200, train/loss_epoch=1.280]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.21it/s]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 16.33it/s, v_num=22, train/loss_step=0.435, val/loss=1.130, val/error_u=0.890, val/error_v=0.963, val/error_h=0.758, val/loss_best=1.130, train/loss_epoch=0.619]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.05it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 17.88it/s, v_num=22, train/loss_step=0.398, val/loss=1.160, val/error_u=0.904, val/error_v=0.987, val/error_h=0.758, val/loss_best=1.130, train/loss_epoch=0.435]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.27it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 17.62it/s, v_num=22, train/loss_step=0.421, val/loss=1.220, val/error_u=0.914, val/error_v=1.060, val/error_h=0.759, val/loss_best=1.130, train/loss_epoch=0.398]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.54it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 17.66it/s, v_num=22, train/loss_step=0.467, val/loss=1.280, val/error_u=0.921, val/error_v=1.140, val/error_h=0.761, val/loss_best=1.130, train/loss_epoch=0.421]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.05it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 16.63it/s, v_num=22, train/loss_step=0.511, val/loss=1.330, val/error_u=0.922, val/error_v=1.210, val/error_h=0.764, val/loss_best=1.130, train/loss_epoch=0.467]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.77it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 17.41it/s, v_num=22, train/loss_step=0.538, val/loss=1.360, val/error_u=0.917, val/error_v=1.260, val/error_h=0.765, val/loss_best=1.130, train/loss_epoch=0.511]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.90it/s]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 17.21it/s, v_num=22, train/loss_step=0.542, val/loss=1.370, val/error_u=0.908, val/error_v=1.280, val/error_h=0.764, val/loss_best=1.130, train/loss_epoch=0.538]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.53it/s]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 17.87it/s, v_num=22, train/loss_step=0.527, val/loss=1.360, val/error_u=0.896, val/error_v=1.280, val/error_h=0.761, val/loss_best=1.130, train/loss_epoch=0.542]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.33it/s]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s, v_num=22, train/loss_step=0.501, val/loss=1.340, val/error_u=0.883, val/error_v=1.270, val/error_h=0.759, val/loss_best=1.130, train/loss_epoch=0.527]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.32it/s]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 17.97it/s, v_num=22, train/loss_step=0.473, val/loss=1.310, val/error_u=0.872, val/error_v=1.240, val/error_h=0.758, val/loss_best=1.130, train/loss_epoch=0.501]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.72it/s]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 18.15it/s, v_num=22, train/loss_step=0.450, val/loss=1.280, val/error_u=0.863, val/error_v=1.210, val/error_h=0.761, val/loss_best=1.130, train/loss_epoch=0.473]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.48it/s]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 17.85it/s, v_num=22, train/loss_step=0.432, val/loss=1.250, val/error_u=0.857, val/error_v=1.180, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.450]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.56it/s]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 17.99it/s, v_num=22, train/loss_step=0.420, val/loss=1.230, val/error_u=0.854, val/error_v=1.140, val/error_h=0.774, val/loss_best=1.130, train/loss_epoch=0.432]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.13it/s]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 17.97it/s, v_num=22, train/loss_step=0.412, val/loss=1.220, val/error_u=0.853, val/error_v=1.100, val/error_h=0.783, val/loss_best=1.130, train/loss_epoch=0.420]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.12it/s]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 18.07it/s, v_num=22, train/loss_step=0.407, val/loss=1.210, val/error_u=0.852, val/error_v=1.070, val/error_h=0.791, val/loss_best=1.130, train/loss_epoch=0.412]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.20it/s]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 18.30it/s, v_num=22, train/loss_step=0.404, val/loss=1.200, val/error_u=0.853, val/error_v=1.050, val/error_h=0.796, val/loss_best=1.130, train/loss_epoch=0.407]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.09it/s]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s, v_num=22, train/loss_step=0.401, val/loss=1.190, val/error_u=0.853, val/error_v=1.030, val/error_h=0.798, val/loss_best=1.130, train/loss_epoch=0.404]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.13it/s]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 18.60it/s, v_num=22, train/loss_step=0.397, val/loss=1.180, val/error_u=0.853, val/error_v=1.010, val/error_h=0.798, val/loss_best=1.130, train/loss_epoch=0.401]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.95it/s]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 18.35it/s, v_num=22, train/loss_step=0.394, val/loss=1.170, val/error_u=0.852, val/error_v=0.997, val/error_h=0.794, val/loss_best=1.130, train/loss_epoch=0.397]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.04it/s]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 17.30it/s, v_num=22, train/loss_step=0.390, val/loss=1.150, val/error_u=0.853, val/error_v=0.987, val/error_h=0.789, val/loss_best=1.130, train/loss_epoch=0.394]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.15it/s]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 17.94it/s, v_num=22, train/loss_step=0.387, val/loss=1.140, val/error_u=0.854, val/error_v=0.980, val/error_h=0.783, val/loss_best=1.130, train/loss_epoch=0.390]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.42it/s]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 18.78it/s, v_num=22, train/loss_step=0.384, val/loss=1.140, val/error_u=0.856, val/error_v=0.976, val/error_h=0.777, val/loss_best=1.130, train/loss_epoch=0.387]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.98it/s]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 18.82it/s, v_num=22, train/loss_step=0.383, val/loss=1.130, val/error_u=0.860, val/error_v=0.972, val/error_h=0.772, val/loss_best=1.130, train/loss_epoch=0.384]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.49it/s]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 18.80it/s, v_num=22, train/loss_step=0.383, val/loss=1.130, val/error_u=0.865, val/error_v=0.970, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.383]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.76it/s]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 18.34it/s, v_num=22, train/loss_step=0.385, val/loss=1.130, val/error_u=0.870, val/error_v=0.969, val/error_h=0.764, val/loss_best=1.130, train/loss_epoch=0.383]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.89it/s]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 18.11it/s, v_num=22, train/loss_step=0.387, val/loss=1.130, val/error_u=0.876, val/error_v=0.969, val/error_h=0.762, val/loss_best=1.130, train/loss_epoch=0.385]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.03it/s]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s, v_num=22, train/loss_step=0.389, val/loss=1.130, val/error_u=0.881, val/error_v=0.969, val/error_h=0.760, val/loss_best=1.130, train/loss_epoch=0.387]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.48it/s]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 18.02it/s, v_num=22, train/loss_step=0.391, val/loss=1.130, val/error_u=0.884, val/error_v=0.970, val/error_h=0.760, val/loss_best=1.130, train/loss_epoch=0.389]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.60it/s]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 18.43it/s, v_num=22, train/loss_step=0.391, val/loss=1.140, val/error_u=0.886, val/error_v=0.971, val/error_h=0.759, val/loss_best=1.130, train/loss_epoch=0.391]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.41it/s]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 18.53it/s, v_num=22, train/loss_step=0.389, val/loss=1.140, val/error_u=0.885, val/error_v=0.972, val/error_h=0.759, val/loss_best=1.130, train/loss_epoch=0.391]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 46.90it/s]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s, v_num=22, train/loss_step=0.387, val/loss=1.140, val/error_u=0.883, val/error_v=0.974, val/error_h=0.760, val/loss_best=1.130, train/loss_epoch=0.389]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.18it/s]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 17.86it/s, v_num=22, train/loss_step=0.383, val/loss=1.140, val/error_u=0.880, val/error_v=0.977, val/error_h=0.761, val/loss_best=1.130, train/loss_epoch=0.387]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.03it/s]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 18.33it/s, v_num=22, train/loss_step=0.380, val/loss=1.140, val/error_u=0.876, val/error_v=0.980, val/error_h=0.762, val/loss_best=1.130, train/loss_epoch=0.383]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.85it/s]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 18.73it/s, v_num=22, train/loss_step=0.377, val/loss=1.140, val/error_u=0.872, val/error_v=0.983, val/error_h=0.764, val/loss_best=1.130, train/loss_epoch=0.380]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.80it/s]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 18.42it/s, v_num=22, train/loss_step=0.376, val/loss=1.140, val/error_u=0.868, val/error_v=0.987, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.377]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.98it/s]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 18.58it/s, v_num=22, train/loss_step=0.375, val/loss=1.140, val/error_u=0.865, val/error_v=0.991, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.40it/s]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 18.42it/s, v_num=22, train/loss_step=0.375, val/loss=1.140, val/error_u=0.862, val/error_v=0.995, val/error_h=0.770, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.18it/s]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s, v_num=22, train/loss_step=0.375, val/loss=1.150, val/error_u=0.860, val/error_v=0.999, val/error_h=0.772, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.83it/s]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 18.39it/s, v_num=22, train/loss_step=0.376, val/loss=1.150, val/error_u=0.859, val/error_v=1.000, val/error_h=0.774, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.97it/s]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 18.47it/s, v_num=22, train/loss_step=0.376, val/loss=1.150, val/error_u=0.859, val/error_v=1.010, val/error_h=0.775, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.26it/s]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00, 18.55it/s, v_num=22, train/loss_step=0.376, val/loss=1.160, val/error_u=0.858, val/error_v=1.010, val/error_h=0.775, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.32it/s]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00, 18.57it/s, v_num=22, train/loss_step=0.376, val/loss=1.160, val/error_u=0.858, val/error_v=1.010, val/error_h=0.775, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 46.24it/s]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00, 18.14it/s, v_num=22, train/loss_step=0.376, val/loss=1.160, val/error_u=0.859, val/error_v=1.020, val/error_h=0.774, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.05it/s]
# Epoch 50: 100%|██████████| 1/1 [00:00<00:00, 18.25it/s, v_num=22, train/loss_step=0.376, val/loss=1.160, val/error_u=0.860, val/error_v=1.020, val/error_h=0.773, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.55it/s]
# Epoch 51: 100%|██████████| 1/1 [00:00<00:00, 18.20it/s, v_num=22, train/loss_step=0.375, val/loss=1.160, val/error_u=0.861, val/error_v=1.020, val/error_h=0.772, val/loss_best=1.130, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 47.58it/s]
# Epoch 52: 100%|██████████| 1/1 [00:00<00:00, 18.07it/s, v_num=22, train/loss_step=0.375, val/loss=1.160, val/error_u=0.863, val/error_v=1.020, val/error_h=0.770, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.92it/s]
# Epoch 53: 100%|██████████| 1/1 [00:00<00:00, 18.38it/s, v_num=22, train/loss_step=0.375, val/loss=1.160, val/error_u=0.864, val/error_v=1.020, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.92it/s]
# Epoch 54: 100%|██████████| 1/1 [00:00<00:00, 17.59it/s, v_num=22, train/loss_step=0.374, val/loss=1.160, val/error_u=0.866, val/error_v=1.020, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.09it/s]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00, 18.52it/s, v_num=22, train/loss_step=0.374, val/loss=1.160, val/error_u=0.867, val/error_v=1.020, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.374]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.60it/s]
# Epoch 56: 100%|██████████| 1/1 [00:00<00:00, 18.41it/s, v_num=22, train/loss_step=0.374, val/loss=1.160, val/error_u=0.868, val/error_v=1.020, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.374]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.25it/s]
# Epoch 57: 100%|██████████| 1/1 [00:00<00:00, 18.14it/s, v_num=22, train/loss_step=0.374, val/loss=1.160, val/error_u=0.869, val/error_v=1.010, val/error_h=0.765, val/loss_best=1.130, train/loss_epoch=0.374]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.46it/s]
# Epoch 58: 100%|██████████| 1/1 [00:00<00:00, 18.16it/s, v_num=22, train/loss_step=0.373, val/loss=1.150, val/error_u=0.870, val/error_v=1.010, val/error_h=0.765, val/loss_best=1.130, train/loss_epoch=0.374]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.72it/s]
# Epoch 59: 100%|██████████| 1/1 [00:00<00:00, 18.01it/s, v_num=22, train/loss_step=0.373, val/loss=1.150, val/error_u=0.870, val/error_v=1.010, val/error_h=0.765, val/loss_best=1.130, train/loss_epoch=0.373]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.91it/s]
# Epoch 60: 100%|██████████| 1/1 [00:00<00:00, 18.38it/s, v_num=22, train/loss_step=0.373, val/loss=1.150, val/error_u=0.869, val/error_v=1.010, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.373]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 43.27it/s]
# Epoch 61: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=22, train/loss_step=0.372, val/loss=1.150, val/error_u=0.869, val/error_v=1.000, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.373]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.96it/s]
# Epoch 62: 100%|██████████| 1/1 [00:00<00:00, 17.18it/s, v_num=22, train/loss_step=0.372, val/loss=1.150, val/error_u=0.868, val/error_v=0.999, val/error_h=0.766, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.72it/s]
# Epoch 63: 100%|██████████| 1/1 [00:00<00:00, 17.87it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.867, val/error_v=0.997, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.28it/s]
# Epoch 64: 100%|██████████| 1/1 [00:00<00:00, 18.02it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.866, val/error_v=0.995, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.23it/s]
# Epoch 65: 100%|██████████| 1/1 [00:00<00:00, 17.58it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.865, val/error_v=0.993, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.48it/s]
# Epoch 66: 100%|██████████| 1/1 [00:00<00:00, 18.09it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.864, val/error_v=0.991, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 48.46it/s]
# Epoch 67: 100%|██████████| 1/1 [00:00<00:00, 17.68it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.864, val/error_v=0.990, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.24it/s]
# Epoch 68: 100%|██████████| 1/1 [00:00<00:00, 17.92it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.864, val/error_v=0.989, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.48it/s]
# Epoch 69: 100%|██████████| 1/1 [00:00<00:00, 17.27it/s, v_num=22, train/loss_step=0.372, val/loss=1.140, val/error_u=0.864, val/error_v=0.989, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 49.69it/s]
# Epoch 70: 100%|██████████| 1/1 [00:00<00:00, 17.45it/s, v_num=22, train/loss_step=0.371, val/loss=1.140, val/error_u=0.864, val/error_v=0.989, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.372]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.09it/s]
# Epoch 71: 100%|██████████| 1/1 [00:00<00:00, 16.84it/s, v_num=22, train/loss_step=0.371, val/loss=1.140, val/error_u=0.864, val/error_v=0.989, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.91it/s]
# Epoch 72: 100%|██████████| 1/1 [00:00<00:00, 17.81it/s, v_num=22, train/loss_step=0.371, val/loss=1.140, val/error_u=0.864, val/error_v=0.990, val/error_h=0.769, val/loss_best=1.130, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.26it/s]
# Epoch 73: 100%|██████████| 1/1 [00:00<00:00, 17.15it/s, v_num=22, train/loss_step=0.371, val/loss=1.140, val/error_u=0.865, val/error_v=0.990, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.38it/s]
# Epoch 74: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s, v_num=22, train/loss_step=0.371, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.87it/s]
# Epoch 75: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.866, val/error_v=0.992, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.22it/s]
# Epoch 76: 100%|██████████| 1/1 [00:00<00:00, 16.73it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.867, val/error_v=0.993, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.83it/s]
# Epoch 77: 100%|██████████| 1/1 [00:00<00:00, 17.58it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.867, val/error_v=0.994, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.03it/s]
# Epoch 78: 100%|██████████| 1/1 [00:00<00:00, 17.39it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.867, val/error_v=0.995, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.60it/s]
# Epoch 79: 100%|██████████| 1/1 [00:00<00:00, 16.96it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.867, val/error_v=0.996, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.40it/s]
# Epoch 80: 100%|██████████| 1/1 [00:00<00:00, 17.45it/s, v_num=22, train/loss_step=0.370, val/loss=1.140, val/error_u=0.867, val/error_v=0.997, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.01it/s]
# Epoch 81: 100%|██████████| 1/1 [00:00<00:00, 17.59it/s, v_num=22, train/loss_step=0.370, val/loss=1.150, val/error_u=0.867, val/error_v=0.997, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.05it/s]
# Epoch 82: 100%|██████████| 1/1 [00:00<00:00, 17.21it/s, v_num=22, train/loss_step=0.370, val/loss=1.150, val/error_u=0.867, val/error_v=0.998, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.72it/s]
# Epoch 83: 100%|██████████| 1/1 [00:00<00:00, 18.04it/s, v_num=22, train/loss_step=0.369, val/loss=1.150, val/error_u=0.866, val/error_v=0.998, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.370]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.17it/s]
# Epoch 84: 100%|██████████| 1/1 [00:00<00:00, 17.72it/s, v_num=22, train/loss_step=0.369, val/loss=1.150, val/error_u=0.866, val/error_v=0.998, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.59it/s]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 17.33it/s, v_num=22, train/loss_step=0.369, val/loss=1.150, val/error_u=0.865, val/error_v=0.998, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.84it/s]
# Epoch 86: 100%|██████████| 1/1 [00:00<00:00, 16.94it/s, v_num=22, train/loss_step=0.369, val/loss=1.150, val/error_u=0.865, val/error_v=0.998, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.23it/s]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 17.27it/s, v_num=22, train/loss_step=0.369, val/loss=1.150, val/error_u=0.865, val/error_v=0.997, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.53it/s]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 17.76it/s, v_num=22, train/loss_step=0.369, val/loss=1.140, val/error_u=0.865, val/error_v=0.997, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 41.24it/s]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 15.18it/s, v_num=22, train/loss_step=0.369, val/loss=1.140, val/error_u=0.865, val/error_v=0.996, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 33.69it/s]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 12.01it/s, v_num=22, train/loss_step=0.369, val/loss=1.140, val/error_u=0.865, val/error_v=0.996, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 42.45it/s]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 16.16it/s, v_num=22, train/loss_step=0.369, val/loss=1.140, val/error_u=0.865, val/error_v=0.995, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.77it/s]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 16.93it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.865, val/error_v=0.995, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 51.02it/s]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 17.59it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.865, val/error_v=0.994, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.36it/s]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 16.80it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.866, val/error_v=0.994, val/error_h=0.768, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.03it/s]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 17.78it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.866, val/error_v=0.993, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.08it/s]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 17.84it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.866, val/error_v=0.993, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 17.17it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.866, val/error_v=0.992, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.19it/s]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 17.43it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.867, val/error_v=0.992, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.33it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 17.14it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.867, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.38it/s]
# Epoch 100: 100%|██████████| 1/1 [00:00<00:00, 17.22it/s, v_num=22, train/loss_step=0.368, val/loss=1.140, val/error_u=0.867, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.33it/s]
# Epoch 101: 100%|██████████| 1/1 [00:00<00:00, 17.63it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.368]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.20it/s]
# Epoch 102: 100%|██████████| 1/1 [00:00<00:00, 18.07it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.367]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.09it/s]
# Epoch 103: 100%|██████████| 1/1 [00:00<00:00, 17.28it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.367]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.19it/s]
# Epoch 104: 100%|██████████| 1/1 [00:00<00:00, 16.14it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.367]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.02it/s]
# Epoch 105: 100%|██████████| 1/1 [00:00<00:00, 18.02it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.367]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.86it/s]
# Epoch 106: 100%|██████████| 1/1 [00:00<00:00, 17.18it/s, v_num=22, train/loss_step=0.367, val/loss=1.140, val/error_u=0.866, val/error_v=0.991, val/error_h=0.767, val/loss_best=1.130, train/loss_epoch=0.367]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.84it/s]
# ...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.33it/s]
# Epoch 965: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=22, train/loss_step=0.0855, val/loss=0.828, val/error_u=0.784, val/error_v=1.030, val/error_h=0.501, val/loss_best=0.813, train/loss_epoch=0.0853]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.38it/s]
# Epoch 966: 100%|██████████| 1/1 [00:00<00:00, 17.40it/s, v_num=22, train/loss_step=0.0857, val/loss=0.824, val/error_u=0.786, val/error_v=1.040, val/error_h=0.491, val/loss_best=0.813, train/loss_epoch=0.0855]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.87it/s]
# Epoch 967: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s, v_num=22, train/loss_step=0.0863, val/loss=0.830, val/error_u=0.784, val/error_v=1.030, val/error_h=0.504, val/loss_best=0.813, train/loss_epoch=0.0857]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.00it/s]
# Epoch 968: 100%|██████████| 1/1 [00:00<00:00, 17.93it/s, v_num=22, train/loss_step=0.0866, val/loss=0.824, val/error_u=0.787, val/error_v=1.040, val/error_h=0.488, val/loss_best=0.813, train/loss_epoch=0.0863]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.14it/s]
# Epoch 969: 100%|██████████| 1/1 [00:00<00:00, 16.11it/s, v_num=22, train/loss_step=0.0883, val/loss=0.833, val/error_u=0.784, val/error_v=1.030, val/error_h=0.508, val/loss_best=0.813, train/loss_epoch=0.0866]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.28it/s]
# Epoch 970: 100%|██████████| 1/1 [00:00<00:00, 16.98it/s, v_num=22, train/loss_step=0.0883, val/loss=0.824, val/error_u=0.788, val/error_v=1.040, val/error_h=0.486, val/loss_best=0.813, train/loss_epoch=0.0883]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.55it/s]
# Epoch 971: 100%|██████████| 1/1 [00:00<00:00, 17.72it/s, v_num=22, train/loss_step=0.0912, val/loss=0.835, val/error_u=0.784, val/error_v=1.030, val/error_h=0.513, val/loss_best=0.813, train/loss_epoch=0.0883]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.29it/s]
# Epoch 972: 100%|██████████| 1/1 [00:00<00:00, 16.14it/s, v_num=22, train/loss_step=0.089, val/loss=0.823, val/error_u=0.788, val/error_v=1.040, val/error_h=0.485, val/loss_best=0.813, train/loss_epoch=0.0912]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.98it/s]
# Epoch 973: 100%|██████████| 1/1 [00:00<00:00, 17.67it/s, v_num=22, train/loss_step=0.0903, val/loss=0.835, val/error_u=0.784, val/error_v=1.030, val/error_h=0.512, val/loss_best=0.813, train/loss_epoch=0.089]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.50it/s]
# Epoch 974: 100%|██████████| 1/1 [00:00<00:00, 18.24it/s, v_num=22, train/loss_step=0.0871, val/loss=0.824, val/error_u=0.787, val/error_v=1.040, val/error_h=0.487, val/loss_best=0.813, train/loss_epoch=0.0903]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.12it/s]
# Epoch 975: 100%|██████████| 1/1 [00:00<00:00, 17.84it/s, v_num=22, train/loss_step=0.0861, val/loss=0.831, val/error_u=0.784, val/error_v=1.030, val/error_h=0.504, val/loss_best=0.813, train/loss_epoch=0.0871]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.19it/s]
# Epoch 976: 100%|██████████| 1/1 [00:00<00:00, 18.49it/s, v_num=22, train/loss_step=0.0847, val/loss=0.826, val/error_u=0.786, val/error_v=1.040, val/error_h=0.491, val/loss_best=0.813, train/loss_epoch=0.0861]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.94it/s]
# Epoch 977: 100%|██████████| 1/1 [00:00<00:00, 17.54it/s, v_num=22, train/loss_step=0.0841, val/loss=0.829, val/error_u=0.785, val/error_v=1.040, val/error_h=0.497, val/loss_best=0.813, train/loss_epoch=0.0847]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.68it/s]
# Epoch 978: 100%|██████████| 1/1 [00:00<00:00, 18.62it/s, v_num=22, train/loss_step=0.0839, val/loss=0.828, val/error_u=0.786, val/error_v=1.040, val/error_h=0.495, val/loss_best=0.813, train/loss_epoch=0.0841]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.56it/s]
# Epoch 979: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s, v_num=22, train/loss_step=0.0841, val/loss=0.827, val/error_u=0.786, val/error_v=1.040, val/error_h=0.492, val/loss_best=0.813, train/loss_epoch=0.0839]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.14it/s]
# Epoch 980: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s, v_num=22, train/loss_step=0.0846, val/loss=0.831, val/error_u=0.785, val/error_v=1.030, val/error_h=0.500, val/loss_best=0.813, train/loss_epoch=0.0841]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.12it/s]
# Epoch 981: 100%|██████████| 1/1 [00:00<00:00, 17.99it/s, v_num=22, train/loss_step=0.085, val/loss=0.826, val/error_u=0.787, val/error_v=1.040, val/error_h=0.488, val/loss_best=0.813, train/loss_epoch=0.0846]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.47it/s]
# Epoch 982: 100%|██████████| 1/1 [00:00<00:00, 17.91it/s, v_num=22, train/loss_step=0.0861, val/loss=0.832, val/error_u=0.785, val/error_v=1.030, val/error_h=0.504, val/loss_best=0.813, train/loss_epoch=0.085]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.35it/s]
# Epoch 983: 100%|██████████| 1/1 [00:00<00:00, 16.90it/s, v_num=22, train/loss_step=0.0859, val/loss=0.825, val/error_u=0.788, val/error_v=1.040, val/error_h=0.486, val/loss_best=0.813, train/loss_epoch=0.0861]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.02it/s]
# Epoch 984: 100%|██████████| 1/1 [00:00<00:00, 18.00it/s, v_num=22, train/loss_step=0.0869, val/loss=0.833, val/error_u=0.785, val/error_v=1.030, val/error_h=0.506, val/loss_best=0.813, train/loss_epoch=0.0859]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.70it/s]
# Epoch 985: 100%|██████████| 1/1 [00:00<00:00, 17.85it/s, v_num=22, train/loss_step=0.0857, val/loss=0.825, val/error_u=0.788, val/error_v=1.040, val/error_h=0.486, val/loss_best=0.813, train/loss_epoch=0.0869]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.48it/s]
# Epoch 986: 100%|██████████| 1/1 [00:00<00:00, 18.13it/s, v_num=22, train/loss_step=0.0857, val/loss=0.832, val/error_u=0.786, val/error_v=1.030, val/error_h=0.503, val/loss_best=0.813, train/loss_epoch=0.0857]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.29it/s]
# Epoch 987: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=22, train/loss_step=0.0845, val/loss=0.826, val/error_u=0.788, val/error_v=1.040, val/error_h=0.487, val/loss_best=0.813, train/loss_epoch=0.0857]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.26it/s]
# Epoch 988: 100%|██████████| 1/1 [00:00<00:00, 18.55it/s, v_num=22, train/loss_step=0.0841, val/loss=0.831, val/error_u=0.786, val/error_v=1.040, val/error_h=0.499, val/loss_best=0.813, train/loss_epoch=0.0845]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.80it/s]
# Epoch 989: 100%|██████████| 1/1 [00:00<00:00, 17.81it/s, v_num=22, train/loss_step=0.0835, val/loss=0.828, val/error_u=0.788, val/error_v=1.040, val/error_h=0.489, val/loss_best=0.813, train/loss_epoch=0.0841]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.14it/s]
# Epoch 990: 100%|██████████| 1/1 [00:00<00:00, 18.19it/s, v_num=22, train/loss_step=0.0832, val/loss=0.830, val/error_u=0.787, val/error_v=1.040, val/error_h=0.496, val/loss_best=0.813, train/loss_epoch=0.0835]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.72it/s]
# Epoch 991: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s, v_num=22, train/loss_step=0.083, val/loss=0.828, val/error_u=0.787, val/error_v=1.040, val/error_h=0.491, val/loss_best=0.813, train/loss_epoch=0.0832]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.80it/s]
# Epoch 992: 100%|██████████| 1/1 [00:00<00:00, 18.02it/s, v_num=22, train/loss_step=0.0828, val/loss=0.829, val/error_u=0.787, val/error_v=1.040, val/error_h=0.494, val/loss_best=0.813, train/loss_epoch=0.083]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.22it/s]
# Epoch 993: 100%|██████████| 1/1 [00:00<00:00, 18.03it/s, v_num=22, train/loss_step=0.0827, val/loss=0.829, val/error_u=0.787, val/error_v=1.040, val/error_h=0.493, val/loss_best=0.813, train/loss_epoch=0.0828]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.48it/s]
# Epoch 994: 100%|██████████| 1/1 [00:00<00:00, 17.91it/s, v_num=22, train/loss_step=0.0827, val/loss=0.828, val/error_u=0.787, val/error_v=1.040, val/error_h=0.492, val/loss_best=0.813, train/loss_epoch=0.0827]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# Epoch 995: 100%|██████████| 1/1 [00:00<00:00, 17.75it/s, v_num=22, train/loss_step=0.0826, val/loss=0.829, val/error_u=0.787, val/error_v=1.040, val/error_h=0.494, val/loss_best=0.813, train/loss_epoch=0.0827]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.28it/s]
# Epoch 996: 100%|██████████| 1/1 [00:00<00:00, 17.44it/s, v_num=22, train/loss_step=0.0826, val/loss=0.828, val/error_u=0.788, val/error_v=1.040, val/error_h=0.490, val/loss_best=0.813, train/loss_epoch=0.0826]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.15it/s]
# Epoch 997: 100%|██████████| 1/1 [00:00<00:00, 15.91it/s, v_num=22, train/loss_step=0.0827, val/loss=0.830, val/error_u=0.787, val/error_v=1.040, val/error_h=0.495, val/loss_best=0.813, train/loss_epoch=0.0826]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 34.18it/s]
# Epoch 998: 100%|██████████| 1/1 [00:00<00:00, 11.23it/s, v_num=22, train/loss_step=0.0828, val/loss=0.828, val/error_u=0.789, val/error_v=1.040, val/error_h=0.488, val/loss_best=0.813, train/loss_epoch=0.0827]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 36.89it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 16.28it/s, v_num=22, train/loss_step=0.083, val/loss=0.832, val/error_u=0.788, val/error_v=1.040, val/error_h=0.496, val/loss_best=0.813, train/loss_epoch=0.0828]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.01it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 10.14it/s, v_num=22, train/loss_step=0.083, val/loss=0.828, val/error_u=0.789, val/error_v=1.040, val/error_h=0.486, val/loss_best=0.813, train/loss_epoch=0.083]
# `Trainer.fit` stopped: `max_epochs=1000` reached.
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00,  8.66it/s, v_num=22, train/loss_step=0.083, val/loss=0.828, val/error_u=0.789, val/error_v=1.040, val/error_h=0.486, val/loss_best=0.813, train/loss_epoch=0.083]
# CPU times: total: 1min 43s
# Wall time: 1min 47s

# %% [markdown]
# ### Validation

# %%
trainer.validate(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        val/error_h        │    0.4855176508426666     │
# │        val/error_u        │     0.78941410779953      │
# │        val/error_v        │    1.0427643060684204     │
# │         val/loss          │    0.8275840282440186     │
# │       val/loss_best       │    0.8132191896438599     │
# └───────────────────────────┴───────────────────────────┘
# [{'val/loss': 0.8275840282440186,
#   'val/error_u': 0.78941410779953,
#   'val/error_v': 1.0427643060684204,
#   'val/error_h': 0.4855176508426666,
#   'val/loss_best': 0.8132191896438599}]

# %% [markdown]
# ### Plotting
#
# For plotting, we need predict the results, and then, we should concatenate the results.

# %%
preds_list = trainer.predict(model=model, datamodule=datamodule)
preds_dict = pinnstorch.utils.fix_predictions(preds_list)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.94it/s]

# %%
pinnstorch.utils.plot_schrodinger(mesh=mesh,
                                  preds=preds_dict,
                                  train_datasets=train_datasets,
                                  val_dataset=val_dataset,
                                  file_name='out')
