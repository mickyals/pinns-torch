# %% [markdown]
# ## Tutorial - 0: Continuous Forward Schrodinger
#
# Welcome to our first tutorial on Physics-Informed Neural Networks (PINNs) using `PyTorch Lightning` and our new package, **`pinnstorch`**! This guide aims to introduce you to the integration of deep learning and scientific computing via PINNs, which embed physical laws into neural network training.
#
# #### Overview:
#
# - **Mesh Generation and Sampling:** Understanding how to create and use meshes for training PINNs, crucial for defining the domain of our problem.
# - **Neural Network Model with PINNs:** How to build and structure a neural network for physical law integration.
# - **Physical Laws in Neural Networks:** Detailing the implementation of differential equations within the network using `pde_fn` and `output_fn`.
# - **Training and Validation:** Utilizing PyTorch Lightning’s Trainer to train our model, including defining the training data, initial conditions, and handling boundary conditions.
# - **Results Visualization:** Saving and analyzing the outcomes of your PINN models.

# %% [markdown]
# #### Install Libraries

# %%
# !pip install pinnstorch
# !pip install lightning
# Out:
# Requirement already satisfied: pinnstorch in c:\users\micke\onedrive - university of toronto\pinns-torch (0.1.2)
# Requirement already satisfied: hydra-core in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.3.2)
# Requirement already satisfied: scipy in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.13.1)
# Requirement already satisfied: pyDOE in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (0.3.8)
# Requirement already satisfied: matplotlib in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (3.10.0)
# Requirement already satisfied: rootutils in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (1.0.7)
# Requirement already satisfied: tqdm in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (4.66.5)
# Requirement already satisfied: rich in c:\users\micke\anaconda3\lib\site-packages (from pinnstorch) (13.7.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (4.9.3)
# Requirement already satisfied: packaging in c:\users\micke\anaconda3\lib\site-packages (from hydra-core->pinnstorch) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\micke\anaconda3\lib\site-packages (from matplotlib->pinnstorch) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\micke\anaconda3\lib\site-packages (from rich->pinnstorch) (2.15.1)
# Requirement already satisfied: python-dotenv>=0.20.0 in c:\users\micke\anaconda3\lib\site-packages (from rootutils->pinnstorch) (0.21.0)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm->pinnstorch) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\micke\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->pinnstorch) (0.1.0)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\micke\anaconda3\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core->pinnstorch) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\micke\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pinnstorch) (1.16.0)
# Requirement already satisfied: lightning in c:\users\micke\anaconda3\lib\site-packages (2.5.5)
# Requirement already satisfied: PyYAML<8.0,>5.4 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (0.11.9)
# Requirement already satisfied: packaging<27.0,>=20.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.3.1)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (1.4.0.post0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.66.5)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in c:\users\micke\anaconda3\lib\site-packages (from lightning) (4.11.0)
# Requirement already satisfied: pytorch-lightning in c:\users\micke\anaconda3\lib\site-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\micke\anaconda3\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (3.10.5)
# Requirement already satisfied: setuptools in c:\users\micke\anaconda3\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: filelock in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.13.1)
# Requirement already satisfied: sympy in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.2)
# Requirement already satisfied: networkx in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\micke\anaconda3\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.4)
# Requirement already satisfied: numpy>1.20.0 in c:\users\micke\anaconda3\lib\site-packages (from torchmetrics<3.0,>0.7.0->lightning) (1.26.4)
# Requirement already satisfied: colorama in c:\users\micke\anaconda3\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\micke\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\micke\anaconda3\lib\site-packages (from sympy->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in c:\users\micke\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (3.7)

# %% [markdown]
# #### Import Libraries

# %%
from typing import Dict

import torch
import numpy as np
import lightning.pytorch as pl

import pinnstorch
from pinnstorch.models.net.activations import SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

# %% [markdown]
# ### Define Mesh
#
# Physics-Informed Neural Networks (PINNs) require a discretized domain (mesh) over which the physical equations are solved. In `pinnstorch`, there are primarily two approaches to define this mesh:
#
#
# - **Defining Time and Spatial Domains Separately:** Here, we use `pinnstorch.data.TimeDomain` and `pinnstorch.data.Interval` for creating 1-D spatial domains. These domains are then used to define a `pinnstorch.data.Mesh`.
#
# - **Defining Point Clouds:** This method involves directly utilizing spatio-temporal data (e.g., from experiments or other simulations) to create a mesh using `pinnstorch.data.PointCloud`.
#
# Both approaches should ideally yield the same results.

# %% [markdown]
# #### Option 1: Defining Mesh with Separate Time and Spatial Domains
#
# We start by defining a function to read and preprocess the solution data from a file. The output should be a dictionary.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in Mesh class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")
    exact = data["uu"] # complex number shape N x T
    exact_u = np.real(exact) # N x T # real part
    exact_v = np.imag(exact) # N x T # imaginary part
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T # absolute value ----> ||X|| = sqrt(x^2 + y^2)
    return {"u": exact_u, "v": exact_v, "h": exact_h} # return dict of solutions {u:real, v:imag, h:absolute value}

# %% [markdown]
# Now, define the time and spatial domains for mesh generation. The choice of these parameters depends on the specific problem being solved and should be set accordingly.

# %%
time_domain = pinnstorch.data.TimeDomain(t_interval=[0, 1.57079633], t_points = 201)
spatial_domain = pinnstorch.data.Interval(x_interval= [-5, 4.9609375], shape = [256, 1])

# %%
help(time_domain)
time_domain
# Out:
# Help on TimeDomain in module pinnstorch.data.domains.time object:
#
# class TimeDomain(builtins.object)
#  |  TimeDomain(t_interval, t_points: int)
#  |
#  |  Initialize a time domain.
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, idx)
#  |      Get a specific time point from the time domain using indexing.
#  |
#  |      :param idx: The index of the desired time point.
#  |      :return: The time value at the specified index.
#  |
#  |  __init__(self, t_interval, t_points: int)
#  |      Initialize a TimeDomain object to represent a time domain.
#  |
#  |      :param t_interval: A tuple or list representing the time interval [start_time, end_time].
#  |      :param t_points: The number of time points to discretize the interval.
#  |
#  |  __len__(self)
#  |      Get the length of the time domain.
#  |
#  |      :return: The number of time points in the time domain.
#  |
#  |  generate_mesh(self, spatial_points)
#  |      Generate a mesh of time based on number of spatial points.
#  |
#  |      :param spatial_points: The number of spatial points.
#  |      :return: A mesh of time and spatial points.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# The mesh is then defined using the time and spatial domains along with the read_data_fn function.

# %%
mesh = pinnstorch.data.Mesh(root_dir='../data',
                            read_data_fn=read_data_fn,
                            spatial_domain = spatial_domain,
                            time_domain = time_domain)

# %% [markdown]
# #### Option 2: Using Point Clouds
#
# For scenarios where the spatial and temporal data along with solutions are directly available (e.g., from experimental measurements), we can create a mesh using `pinnstorch.data.PointCloud`.
#
# **Note:** It's crucial to format the spatial and temporal domain dimensions correctly. Specifically:
#
# - **Spatial Domain:** Each axis should be structured in the shape of $(N \times 1)$, where $N$ represents the number of spatial points.
# - **Time Domain:** This should be formatted as $(T \times 1)$, where $T$ indicates the number of time steps.
# - **Solution Data:** Each solution variable (e.g., temperature, velocity) should be in the shape of $(N \times T)$, aligning with the spatial and temporal points.

# %%
def read_data_fn(root_path):
    """Read and preprocess data from the specified root path.

    :param root_path: The root directory containing the data.
    :return: Processed data will be used in PointCloud class.
    """

    data = pinnstorch.utils.load_data(root_path, "NLS.mat")

    x = data["x"].T  # N x 1
    t = data["tt"].T  # T x 1
    
    exact = data["uu"]
    exact_u = np.real(exact) # N x T
    exact_v = np.imag(exact) # N x T
    exact_h = np.sqrt(exact_u**2 + exact_v**2) # N x T

    print(f" x has {x.shape} shape with min: {x.min()}, max: {x.max()}")
    print(f" t has {t.shape} shape with min: {t.min()}, max: {t.max()}")
    print(f"  exact_u {exact_u.shape} shape with min: {exact_u.min()}, max: {exact_u.max()}")
    print(f" exact_v {exact_v.shape} shape with min: {exact_v.min()}, max: {exact_v.max()}")
    print(f" exact_h  {exact_h.shape} shape with min: {exact_h.min()}, max: {exact_h.max()}")


    
    return pinnstorch.data.PointCloudData(
            spatial=[x], time=[t], solution={"u": exact_u, "v": exact_v, "h": exact_h}
    )

# %% [markdown]
# Now, mesh can be initalize with using the function and the directory to the folder of data.

# %%
mesh = pinnstorch.data.PointCloud(root_dir='./data',
                                  read_data_fn=read_data_fn)
# Out:
#  x has (256, 1) shape with min: -5.0, max: 4.9609375
#  t has (201, 1) shape with min: 0.0, max: 1.5707963267948966
#   exact_u (256, 201) shape with min: -3.932425448799453, max: 2.1998422786360754
#  exact_v (256, 201) shape with min: -3.4523031901896957, max: 2.754265786698505
#  exact_h  (256, 201) shape with min: 0.015981892796576278, max: 3.9987582390710266

# %% [markdown]
# ### Define Train datasets

# %% [markdown]
# For solving Schrodinger PDE, we have:
# - Initial condition
# - Periodic boundary condition
# - Collection points for the PDE.

# %% [markdown]
# #### Initial Condition
#
# Let's start with initial condition of the Schrodinger.
# $$ u(0, x) = 2 \text{sech}(x) $$
# $$ v(0, x) = 0 $$
#
# For defining initial condition, again we have two options.
#
# - **Sample from the data.**
# - **Defining a function for calculating initial condition.**

# %% [markdown]
# ##### Set number of samples

# %%
N0 = 50

# %% [markdown]
# ##### Option 1: Sample from the data

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        solution = ['u', 'v'])

# %% [markdown]
# ##### Option 2: Defining a function for calculating initial condition

# %% [markdown]
# The input of `initial_fun` should be the same as spatial domain of the problem.

# %%
def initial_fun(x):
    return {'u': 2*1/np.cosh(x), 'v': np.zeros_like(x)}

# %%
in_c = pinnstorch.data.InitialCondition(mesh = mesh,
                                        num_sample = N0,
                                        initial_fun = initial_fun,
                                        solution = ['u', 'v'])

# %% [markdown]
# The `solution` attribute in `pinnstorch.data.InitialCondition` specifies the solutions (`u` and `v` in our case) to be sampled for initial conditions.

# %% [markdown]
# #### Periodic Boundary Condition

# %% [markdown]
# The `pinnstorch.data.PeriodicBoundaryCondition` is used to sample periodic points from the upper and lower bounds of the spatial domain (mesh). The `derivative_order` parameter specifies the order of the derivative to be matched at these boundaries. In our case, for the Schrödinger equation, both the function and its first spatial derivative should match at the boundaries, hence `derivative_order = 1`.
#
#
# $$ u(t,-5) = u(t, 5), $$
# $$ v(t,-5) = v(t, 5), $$
# $$ u_x(t,-5) = u_x(t, 5),$$
# $$ v_x(t,-5) = v_x(t, 5) $$

# %%
N_b = 50
pe_b = pinnstorch.data.PeriodicBoundaryCondition(mesh = mesh,
                                                 num_sample = 50,
                                                 derivative_order = 1,
                                                 solution = ['u', 'v'])

# %% [markdown]
# #### Mesh Sampler for collection points and solutions
#
# In our problem, the partial differential equations (PDEs) governing the dynamics are given by:
#
# $$ f_u := u_t + 0.5v_{xx} + v(u^2 +v^2),$$
# $$ f_v := v_t + 0.5u_{xx} + u(u^2 +v^2) $$
#
# To find the solutions to these PDEs using a neural network, we must sample points from the domain at which the network will be trained to satisfy these equations. This sampling process is crucial for training our PINN. We utilize the `pinnstorch.data.MeshSampler` for this purpose, specifying the following:
#
# - **Number of Sample Points (N_f):** We choose to sample 20,000 points from the domain. This number is a balance between computational efficiency and the need for a sufficiently dense sampling to capture the dynamics of the PDEs.
# - **Mesh (mesh):** This parameter defines the spatial-temporal domain from which the points will be sampled.
# - **Collection Points:** We define `['f_u', 'f_v']` as the targets for our collection points. These are not direct outputs from the neural network but are derived from the network outputs and their derivatives (We will define `pde_fn` function later). The PINN will be trained such that these expressions tend towards zero, aligning with the PDE constraints.
#
# Here's the code to implement this sampler:

# %%
N_f = 20000
me_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                   num_sample = N_f,
                                   collection_points = ['f_v', 'f_u'])

# %% [markdown]
# ### Define Validation dataset
#
# For validation, we sample all points from the mesh to evaluate our model comprehensively. Model will be validated for solutions of `u`, `v`, and `h`.
#
# **Note:** If `num_sample` is not specified, the sampler will use the entire mesh for data sampling.

# %%
val_s = pinnstorch.data.MeshSampler(mesh = mesh,
                                    solution = ['u', 'v', 'h'])

# %%
# SineActivation, GaussianActivation, WireActivation, HoscActivation, SincActivation

net = pinnstorch.models.FCN(layers = [2, 100, 100, 100, 100, 2],
                            output_names = ['u', 'v'],
                            lb=mesh.lb,
                            ub=mesh.ub,
                            activation="GAUSSIAN_FINER",                  # use registry
                            activation_kwargs={'sigma':5, 'omega':0.5},    # extra params
                            initializer="XAVIER_UNIFORM_FINER",                # use registry
                            initializer_kwargs={}, # extra params
                            layer_type='BASE',
                            layer_kwargs={}
                             )

# %% [markdown]
# ### Define `pde_fn` and `output_fn` functions
#
# Now, we define `pde_fn` and `output_fn`.
# - **`output_fn`:** is applied to the network's output, adding any necessary post-processing computations. For example, in our case, `h(x,t) = u(x,t)**2 + v(x,t)**2`, thus, we define this equation in `output_fn`.
# - **`pde_fn`:** formulates the PDE constraints, which will be used by the `MeshSampler` to compute the loss at the collection points.

# %% [markdown]
# #### `output_fn` function
#
# **Note:** `output_fn` should always have these inputs:
# - **Outputs:** It is output of the network. In our case, this dictionary should have two output: `u` and `v`.
# - **Spatial domains:** These are the spatial domain variables. In our case, because our problem has 1-D spatial domain, the input just have `x`. For example, if we had 2-D space, we need another input for that dimention. For example, the inputs from `(outputs, x, t)` will be changed to `(outputs, x, y, t)`.
# - **Time domin:** The last input of `output_fn` function always should be time.

# %%
def output_fn(outputs: Dict[str, torch.Tensor],
              x: torch.Tensor,
              t: torch.Tensor):
    """Define `output_fn` function that will be applied to outputs of net."""

    outputs["h"] = torch.sqrt(outputs["u"] ** 2 + outputs["v"] ** 2)

    return outputs

# %% [markdown]
# #### `pde_fn` function
#
# The inputs are similar to `output_fn`. Only if we have extra variables for training (i.g. in inverse problems), we should add input at the end of inputs. For example, `(outputs, x, t)` will be `(outputs, x, t, extra_variable)`. `extra_variable` is always a dictionary.

# %%
def pde_fn(outputs: Dict[str, torch.Tensor],
           x: torch.Tensor,
           t: torch.Tensor):   
    """Define the partial differential equations (PDEs)."""
    u_x, u_t = pinnstorch.utils.gradient(outputs["u"], [x, t])
    v_x, v_t = pinnstorch.utils.gradient(outputs["v"], [x, t])

    u_xx = pinnstorch.utils.gradient(u_x, x)[0]
    v_xx = pinnstorch.utils.gradient(v_x, x)[0]

    outputs["f_u"] = u_t + 0.5 * v_xx + (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["v"]
    outputs["f_v"] = v_t - 0.5 * u_xx - (outputs["u"] ** 2 + outputs["v"] ** 2) * outputs["u"]

    return outputs

# %% [markdown]
# ### Define PINNDataModule and PINNModule
#
# To integrate with Lightning, we utilize two specialized modules:
#
# - `PINNDataModule` (inherited from `LightningDataModule`) manages data.
# - `PINNModule` (derived from `LightningModule`) handles the model, compilation, and various enhancements like AMP.

# %% [markdown]
# #### Define `PINNDataModule`
# Here, we define collection points, initial condition, and preiodic boundary condition as training datasets, and also, we set validation set. `PINNDataModule` is used for defining training, validation, prediction, and test datasets.

# %%
train_datasets = [me_s, in_c, pe_b]
val_dataset = val_s
datamodule = pinnstorch.data.PINNDataModule(train_datasets = [me_s, in_c, pe_b],
                                            val_dataset = val_dataset,
                                            pred_dataset = val_s)

# %% [markdown]
# #### Define `PINNModule`
#
# `PINNModule` handle several things. Here, we will explore the inputs of this class:
# - **net:**  The neural network.
# - **pde_fn:** The function representing the PDE to solve.
# - **optimizer:**  (Optional) The optimizer for training. The default is Adam
# - **loss_fn:** (Optional) The loss function to use, either "sse" or "mse". The default is "sse".
# - **scheduler:** (Optional) Learning rate scheduler. The default is None.
# - **scaler:** (Optional) Gradient scaler for AMP. The default is `torch.cuda.amp.GradScaler`.
# - **extra_variables:** (Optional) Extra variables in inverse problems. The default is None.
# - **output_fn:** (Optional) function to process the model's output. The default is None.
# - **runge_kutta:** (Optional) Runge-Kutta method for solving PDEs in discrete mode. The default is None.
# - **cudagraph_compile:** Flag to enable CUDA Graph compilation. It works only with a single GPU. The default is True.
# - **jit_compile:** (Optional) Flag to enable JIT compilation. The default is True.
# - **amp:** (Optional) Flag to enable Automatic Mixed Precision (AMP). The default is False.
# - **inline:** (Optional) Flag to enable inline mode in JIT compilation. The default is False.
#
# In this example, we initalize `PINNModule` with defined variables. We set Adam optimizer and try to compile the model with CUDA Graph. The loss function here is Mean Square Error (MSE).

# %%
model = pinnstorch.models.PINNModule(net = net,
                                     pde_fn = pde_fn,
                                     output_fn = output_fn,
                                     loss_fn = 'mse')

# %% [markdown]
# ### Setting Up the Trainer
#
# For training our model, we configure a trainer in PyTorch Lightning. Currently, our setup uses a single GPU, as models compiled with CUDA Graph don't support multiple GPUs yet. For a comprehensive understanding of the trainer's options and functionalities, refer to the [official documentation](https://lightning.ai/docs/pytorch/stable/api/lightning.pytorch.trainer.trainer.Trainer.html). For example, arguments that you can set are:
# - **accelerator:**  Supports passing different accelerator types such as `cpu`, `gpu`, `tpu`, `ipu`, `hpu`, `mps`, and `auto`.
# - **devices:** The devices to use. Can be set to a positive number (int or str), a sequence of device indices (list or str), the value -1 to indicate all available devices should be used, or "auto" for automatic selection based on the chosen accelerator. Default: "auto".
# - **max_epochs:** Stop training once this number of epochs is reached.
# - **max_steps:** Stop training after this number of steps.
# - ...
#
# In our example, we configure the trainer for CPU use, specifying one device:

# %%
trainer = pl.Trainer(accelerator='gpu', devices=1, max_epochs = 1000)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# ### Training

# %%
# %%time
trainer.fit(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type       | Params | Mode
# -----------------------------------------------------
# 0 | net           | FCN        | 30.8 K | train
# 1 | train_loss    | MeanMetric | 0      | train
# 2 | val_loss      | MeanMetric | 0      | train
# 3 | val_error     | MeanMetric | 0      | train
# 4 | test_loss     | MeanMetric | 0      | train
# 5 | test_error    | MeanMetric | 0      | train
# 6 | val_loss_best | MinMetric  | 0      | train
# -----------------------------------------------------
# 30.8 K    Trainable params
# 0         Non-trainable params
# 30.8 K    Total params
# 0.123     Total estimated model params size (MB)
# 23        Modules in train mode
# 0         Modules in eval mode
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# C:\Users\micke\anaconda3\envs\myenv\lib\site-packages\torch\jit\_trace.py:165: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   if a.grad is not None:
# Epoch 0: 100%|██████████| 1/1 [00:02<00:00,  0.50it/s, v_num=47, train/loss_step=24.20]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.99it/s]
# Epoch 1: 100%|██████████| 1/1 [00:08<00:00,  0.12it/s, v_num=47, train/loss_step=16.30, val/loss=2.380, val/error_u=1.060, val/error_v=1.940, val/error_h=0.925, val/loss_best=2.380, train/loss_epoch=24.20]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 39.96it/s]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  5.07it/s, v_num=47, train/loss_step=12.30, val/loss=2.240, val/error_u=1.060, val/error_v=1.850, val/error_h=0.900, val/loss_best=2.240, train/loss_epoch=16.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 41.23it/s]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  9.90it/s, v_num=47, train/loss_step=9.560, val/loss=2.120, val/error_u=1.070, val/error_v=1.750, val/error_h=0.882, val/loss_best=2.120, train/loss_epoch=12.30]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.34it/s]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00, 10.73it/s, v_num=47, train/loss_step=7.960, val/loss=2.030, val/error_u=1.060, val/error_v=1.700, val/error_h=0.867, val/loss_best=2.030, train/loss_epoch=9.560]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.26it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 11.39it/s, v_num=47, train/loss_step=7.140, val/loss=1.970, val/error_u=1.040, val/error_v=1.680, val/error_h=0.851, val/loss_best=1.970, train/loss_epoch=7.960]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.61it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 12.92it/s, v_num=47, train/loss_step=6.290, val/loss=1.910, val/error_u=1.020, val/error_v=1.670, val/error_h=0.830, val/loss_best=1.910, train/loss_epoch=7.140]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.44it/s]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 13.76it/s, v_num=47, train/loss_step=5.330, val/loss=1.860, val/error_u=1.010, val/error_v=1.660, val/error_h=0.808, val/loss_best=1.860, train/loss_epoch=6.290]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 74.41it/s]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00, 13.91it/s, v_num=47, train/loss_step=4.740, val/loss=1.810, val/error_u=0.995, val/error_v=1.650, val/error_h=0.791, val/loss_best=1.810, train/loss_epoch=5.330]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.10it/s]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00, 14.26it/s, v_num=47, train/loss_step=4.440, val/loss=1.780, val/error_u=0.987, val/error_v=1.630, val/error_h=0.782, val/loss_best=1.780, train/loss_epoch=4.740]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.80it/s]
# Epoch 10: 100%|██████████| 1/1 [00:00<00:00, 13.86it/s, v_num=47, train/loss_step=4.090, val/loss=1.760, val/error_u=0.980, val/error_v=1.620, val/error_h=0.778, val/loss_best=1.760, train/loss_epoch=4.440]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.04it/s]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 15.33it/s, v_num=47, train/loss_step=3.700, val/loss=1.740, val/error_u=0.974, val/error_v=1.610, val/error_h=0.776, val/loss_best=1.740, train/loss_epoch=4.090]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.99it/s]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 15.71it/s, v_num=47, train/loss_step=3.400, val/loss=1.730, val/error_u=0.971, val/error_v=1.610, val/error_h=0.778, val/loss_best=1.730, train/loss_epoch=3.700]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.48it/s]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00, 16.00it/s, v_num=47, train/loss_step=3.130, val/loss=1.720, val/error_u=0.966, val/error_v=1.590, val/error_h=0.780, val/loss_best=1.720, train/loss_epoch=3.400]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.89it/s]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 14.92it/s, v_num=47, train/loss_step=2.870, val/loss=1.690, val/error_u=0.959, val/error_v=1.570, val/error_h=0.781, val/loss_best=1.690, train/loss_epoch=3.130]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.13it/s]
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00, 14.72it/s, v_num=47, train/loss_step=2.640, val/loss=1.660, val/error_u=0.951, val/error_v=1.550, val/error_h=0.780, val/loss_best=1.660, train/loss_epoch=2.870]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.44it/s]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 16.40it/s, v_num=47, train/loss_step=2.440, val/loss=1.630, val/error_u=0.943, val/error_v=1.530, val/error_h=0.778, val/loss_best=1.630, train/loss_epoch=2.640]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.54it/s]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00, 18.32it/s, v_num=47, train/loss_step=2.270, val/loss=1.600, val/error_u=0.936, val/error_v=1.510, val/error_h=0.774, val/loss_best=1.600, train/loss_epoch=2.440]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.79it/s]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00, 16.18it/s, v_num=47, train/loss_step=2.110, val/loss=1.580, val/error_u=0.931, val/error_v=1.490, val/error_h=0.770, val/loss_best=1.580, train/loss_epoch=2.270]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.02it/s]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00, 17.64it/s, v_num=47, train/loss_step=1.960, val/loss=1.560, val/error_u=0.926, val/error_v=1.480, val/error_h=0.768, val/loss_best=1.560, train/loss_epoch=2.110]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.91it/s]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 16.49it/s, v_num=47, train/loss_step=1.840, val/loss=1.540, val/error_u=0.922, val/error_v=1.460, val/error_h=0.767, val/loss_best=1.540, train/loss_epoch=1.960]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.08it/s]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 16.54it/s, v_num=47, train/loss_step=1.710, val/loss=1.530, val/error_u=0.919, val/error_v=1.450, val/error_h=0.769, val/loss_best=1.530, train/loss_epoch=1.840]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.38it/s]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s, v_num=47, train/loss_step=1.600, val/loss=1.510, val/error_u=0.918, val/error_v=1.430, val/error_h=0.772, val/loss_best=1.510, train/loss_epoch=1.710]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.87it/s]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 16.25it/s, v_num=47, train/loss_step=1.510, val/loss=1.500, val/error_u=0.919, val/error_v=1.410, val/error_h=0.775, val/loss_best=1.500, train/loss_epoch=1.600]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.69it/s]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00, 15.56it/s, v_num=47, train/loss_step=1.430, val/loss=1.490, val/error_u=0.920, val/error_v=1.390, val/error_h=0.778, val/loss_best=1.490, train/loss_epoch=1.510]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.19it/s]
# Epoch 25: 100%|██████████| 1/1 [00:00<00:00, 15.89it/s, v_num=47, train/loss_step=1.350, val/loss=1.490, val/error_u=0.923, val/error_v=1.380, val/error_h=0.781, val/loss_best=1.490, train/loss_epoch=1.430]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 51.53it/s]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 15.75it/s, v_num=47, train/loss_step=1.280, val/loss=1.490, val/error_u=0.925, val/error_v=1.370, val/error_h=0.785, val/loss_best=1.490, train/loss_epoch=1.350]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.84it/s]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00, 15.78it/s, v_num=47, train/loss_step=1.230, val/loss=1.480, val/error_u=0.925, val/error_v=1.360, val/error_h=0.787, val/loss_best=1.480, train/loss_epoch=1.280]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.67it/s]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 17.44it/s, v_num=47, train/loss_step=1.180, val/loss=1.470, val/error_u=0.922, val/error_v=1.350, val/error_h=0.789, val/loss_best=1.470, train/loss_epoch=1.230]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.17it/s]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00, 15.81it/s, v_num=47, train/loss_step=1.120, val/loss=1.460, val/error_u=0.919, val/error_v=1.340, val/error_h=0.790, val/loss_best=1.460, train/loss_epoch=1.180]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.07it/s]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 16.23it/s, v_num=47, train/loss_step=1.070, val/loss=1.450, val/error_u=0.916, val/error_v=1.330, val/error_h=0.791, val/loss_best=1.450, train/loss_epoch=1.120]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.14it/s]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 17.31it/s, v_num=47, train/loss_step=1.020, val/loss=1.440, val/error_u=0.915, val/error_v=1.320, val/error_h=0.792, val/loss_best=1.440, train/loss_epoch=1.070]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.55it/s]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 16.84it/s, v_num=47, train/loss_step=0.981, val/loss=1.440, val/error_u=0.914, val/error_v=1.310, val/error_h=0.794, val/loss_best=1.440, train/loss_epoch=1.020]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 45.19it/s]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00, 16.24it/s, v_num=47, train/loss_step=0.944, val/loss=1.430, val/error_u=0.914, val/error_v=1.300, val/error_h=0.795, val/loss_best=1.430, train/loss_epoch=0.981]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.36it/s]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 18.36it/s, v_num=47, train/loss_step=0.908, val/loss=1.420, val/error_u=0.914, val/error_v=1.290, val/error_h=0.795, val/loss_best=1.420, train/loss_epoch=0.944]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.71it/s]
# Epoch 35: 100%|██████████| 1/1 [00:00<00:00, 16.76it/s, v_num=47, train/loss_step=0.875, val/loss=1.410, val/error_u=0.913, val/error_v=1.280, val/error_h=0.795, val/loss_best=1.410, train/loss_epoch=0.908]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.53it/s]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00, 17.76it/s, v_num=47, train/loss_step=0.846, val/loss=1.410, val/error_u=0.910, val/error_v=1.270, val/error_h=0.795, val/loss_best=1.410, train/loss_epoch=0.875]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.51it/s]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00, 17.75it/s, v_num=47, train/loss_step=0.819, val/loss=1.400, val/error_u=0.907, val/error_v=1.270, val/error_h=0.793, val/loss_best=1.400, train/loss_epoch=0.846]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.98it/s]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00, 17.24it/s, v_num=47, train/loss_step=0.790, val/loss=1.390, val/error_u=0.904, val/error_v=1.260, val/error_h=0.792, val/loss_best=1.390, train/loss_epoch=0.819]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.68it/s]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s, v_num=47, train/loss_step=0.762, val/loss=1.380, val/error_u=0.902, val/error_v=1.260, val/error_h=0.790, val/loss_best=1.380, train/loss_epoch=0.790]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.57it/s]
# Epoch 40: 100%|██████████| 1/1 [00:00<00:00, 16.03it/s, v_num=47, train/loss_step=0.736, val/loss=1.380, val/error_u=0.901, val/error_v=1.250, val/error_h=0.788, val/loss_best=1.380, train/loss_epoch=0.762]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.30it/s]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00, 17.80it/s, v_num=47, train/loss_step=0.713, val/loss=1.370, val/error_u=0.900, val/error_v=1.250, val/error_h=0.787, val/loss_best=1.370, train/loss_epoch=0.736]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.17it/s]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 16.45it/s, v_num=47, train/loss_step=0.691, val/loss=1.360, val/error_u=0.900, val/error_v=1.240, val/error_h=0.786, val/loss_best=1.360, train/loss_epoch=0.713]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 50.09it/s]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00, 16.84it/s, v_num=47, train/loss_step=0.669, val/loss=1.360, val/error_u=0.899, val/error_v=1.240, val/error_h=0.785, val/loss_best=1.360, train/loss_epoch=0.691]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.63it/s]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 15.43it/s, v_num=47, train/loss_step=0.650, val/loss=1.350, val/error_u=0.896, val/error_v=1.230, val/error_h=0.784, val/loss_best=1.350, train/loss_epoch=0.669]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.86it/s]
# Epoch 45: 100%|██████████| 1/1 [00:00<00:00, 16.89it/s, v_num=47, train/loss_step=0.631, val/loss=1.340, val/error_u=0.894, val/error_v=1.220, val/error_h=0.783, val/loss_best=1.340, train/loss_epoch=0.650]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.11it/s]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00, 16.36it/s, v_num=47, train/loss_step=0.614, val/loss=1.330, val/error_u=0.891, val/error_v=1.210, val/error_h=0.781, val/loss_best=1.330, train/loss_epoch=0.631]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.07it/s]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00, 14.63it/s, v_num=47, train/loss_step=0.599, val/loss=1.320, val/error_u=0.889, val/error_v=1.200, val/error_h=0.779, val/loss_best=1.320, train/loss_epoch=0.614]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.68it/s]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00, 16.14it/s, v_num=47, train/loss_step=0.584, val/loss=1.310, val/error_u=0.887, val/error_v=1.200, val/error_h=0.778, val/loss_best=1.310, train/loss_epoch=0.599]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.72it/s]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00, 16.65it/s, v_num=47, train/loss_step=0.569, val/loss=1.300, val/error_u=0.886, val/error_v=1.190, val/error_h=0.777, val/loss_best=1.300, train/loss_epoch=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.33it/s]
# Epoch 50: 100%|██████████| 1/1 [00:00<00:00, 17.60it/s, v_num=47, train/loss_step=0.555, val/loss=1.300, val/error_u=0.885, val/error_v=1.180, val/error_h=0.777, val/loss_best=1.300, train/loss_epoch=0.569]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.61it/s]
# Epoch 51: 100%|██████████| 1/1 [00:00<00:00, 15.95it/s, v_num=47, train/loss_step=0.542, val/loss=1.290, val/error_u=0.884, val/error_v=1.180, val/error_h=0.776, val/loss_best=1.290, train/loss_epoch=0.555]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.96it/s]
# Epoch 52: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=47, train/loss_step=0.530, val/loss=1.280, val/error_u=0.882, val/error_v=1.170, val/error_h=0.776, val/loss_best=1.280, train/loss_epoch=0.542]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.28it/s]
# Epoch 53: 100%|██████████| 1/1 [00:00<00:00, 15.40it/s, v_num=47, train/loss_step=0.519, val/loss=1.280, val/error_u=0.880, val/error_v=1.170, val/error_h=0.775, val/loss_best=1.280, train/loss_epoch=0.530]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.50it/s]
# Epoch 54: 100%|██████████| 1/1 [00:00<00:00, 15.93it/s, v_num=47, train/loss_step=0.508, val/loss=1.270, val/error_u=0.879, val/error_v=1.160, val/error_h=0.774, val/loss_best=1.270, train/loss_epoch=0.519]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.63it/s]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00, 16.32it/s, v_num=47, train/loss_step=0.497, val/loss=1.270, val/error_u=0.877, val/error_v=1.160, val/error_h=0.773, val/loss_best=1.270, train/loss_epoch=0.508]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.49it/s]
# Epoch 56: 100%|██████████| 1/1 [00:00<00:00, 15.34it/s, v_num=47, train/loss_step=0.488, val/loss=1.260, val/error_u=0.875, val/error_v=1.150, val/error_h=0.772, val/loss_best=1.260, train/loss_epoch=0.497]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 43.86it/s]
# Epoch 57: 100%|██████████| 1/1 [00:00<00:00, 15.62it/s, v_num=47, train/loss_step=0.478, val/loss=1.250, val/error_u=0.874, val/error_v=1.150, val/error_h=0.771, val/loss_best=1.250, train/loss_epoch=0.488]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 47.90it/s]
# Epoch 58: 100%|██████████| 1/1 [00:00<00:00, 15.77it/s, v_num=47, train/loss_step=0.469, val/loss=1.250, val/error_u=0.872, val/error_v=1.140, val/error_h=0.770, val/loss_best=1.250, train/loss_epoch=0.478]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.79it/s]
# Epoch 59: 100%|██████████| 1/1 [00:00<00:00, 16.97it/s, v_num=47, train/loss_step=0.460, val/loss=1.240, val/error_u=0.870, val/error_v=1.140, val/error_h=0.768, val/loss_best=1.240, train/loss_epoch=0.469]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.76it/s]
# Epoch 60: 100%|██████████| 1/1 [00:00<00:00, 15.81it/s, v_num=47, train/loss_step=0.452, val/loss=1.230, val/error_u=0.869, val/error_v=1.130, val/error_h=0.767, val/loss_best=1.230, train/loss_epoch=0.460]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.79it/s]
# Epoch 61: 100%|██████████| 1/1 [00:00<00:00, 16.23it/s, v_num=47, train/loss_step=0.444, val/loss=1.230, val/error_u=0.868, val/error_v=1.120, val/error_h=0.766, val/loss_best=1.230, train/loss_epoch=0.452]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 60.37it/s]
# Epoch 62: 100%|██████████| 1/1 [00:00<00:00, 16.77it/s, v_num=47, train/loss_step=0.435, val/loss=1.220, val/error_u=0.866, val/error_v=1.120, val/error_h=0.765, val/loss_best=1.220, train/loss_epoch=0.444]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.11it/s]
# Epoch 63: 100%|██████████| 1/1 [00:00<00:00, 13.78it/s, v_num=47, train/loss_step=0.428, val/loss=1.210, val/error_u=0.865, val/error_v=1.110, val/error_h=0.764, val/loss_best=1.210, train/loss_epoch=0.435]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 31.29it/s]
# Epoch 64: 100%|██████████| 1/1 [00:00<00:00, 11.24it/s, v_num=47, train/loss_step=0.421, val/loss=1.210, val/error_u=0.865, val/error_v=1.110, val/error_h=0.763, val/loss_best=1.210, train/loss_epoch=0.428]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 32.84it/s]
# Epoch 65: 100%|██████████| 1/1 [00:00<00:00, 10.12it/s, v_num=47, train/loss_step=0.414, val/loss=1.210, val/error_u=0.864, val/error_v=1.110, val/error_h=0.762, val/loss_best=1.210, train/loss_epoch=0.421]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 30.47it/s]
# Epoch 66: 100%|██████████| 1/1 [00:00<00:00, 13.64it/s, v_num=47, train/loss_step=0.407, val/loss=1.200, val/error_u=0.863, val/error_v=1.100, val/error_h=0.761, val/loss_best=1.200, train/loss_epoch=0.414]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 48.95it/s]
# Epoch 67: 100%|██████████| 1/1 [00:00<00:00, 14.79it/s, v_num=47, train/loss_step=0.400, val/loss=1.200, val/error_u=0.862, val/error_v=1.100, val/error_h=0.760, val/loss_best=1.200, train/loss_epoch=0.407]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.63it/s]
# Epoch 68: 100%|██████████| 1/1 [00:00<00:00, 14.95it/s, v_num=47, train/loss_step=0.394, val/loss=1.190, val/error_u=0.861, val/error_v=1.090, val/error_h=0.758, val/loss_best=1.190, train/loss_epoch=0.400]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 49.93it/s]
# Epoch 69: 100%|██████████| 1/1 [00:00<00:00, 15.75it/s, v_num=47, train/loss_step=0.388, val/loss=1.180, val/error_u=0.859, val/error_v=1.090, val/error_h=0.756, val/loss_best=1.180, train/loss_epoch=0.394]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.89it/s]
# Epoch 70: 100%|██████████| 1/1 [00:00<00:00, 15.16it/s, v_num=47, train/loss_step=0.382, val/loss=1.180, val/error_u=0.858, val/error_v=1.080, val/error_h=0.754, val/loss_best=1.180, train/loss_epoch=0.388]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 48.49it/s]
# Epoch 71: 100%|██████████| 1/1 [00:00<00:00, 15.25it/s, v_num=47, train/loss_step=0.376, val/loss=1.170, val/error_u=0.856, val/error_v=1.080, val/error_h=0.752, val/loss_best=1.170, train/loss_epoch=0.382]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.70it/s]
# Epoch 72: 100%|██████████| 1/1 [00:00<00:00, 17.00it/s, v_num=47, train/loss_step=0.371, val/loss=1.160, val/error_u=0.855, val/error_v=1.070, val/error_h=0.750, val/loss_best=1.160, train/loss_epoch=0.376]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.42it/s]
# Epoch 73: 100%|██████████| 1/1 [00:00<00:00, 16.32it/s, v_num=47, train/loss_step=0.365, val/loss=1.160, val/error_u=0.853, val/error_v=1.070, val/error_h=0.749, val/loss_best=1.160, train/loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 51.19it/s]
# Epoch 74: 100%|██████████| 1/1 [00:00<00:00, 15.73it/s, v_num=47, train/loss_step=0.360, val/loss=1.150, val/error_u=0.852, val/error_v=1.070, val/error_h=0.747, val/loss_best=1.150, train/loss_epoch=0.365]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.67it/s]
# Epoch 75: 100%|██████████| 1/1 [00:00<00:00, 17.67it/s, v_num=47, train/loss_step=0.355, val/loss=1.150, val/error_u=0.851, val/error_v=1.060, val/error_h=0.745, val/loss_best=1.150, train/loss_epoch=0.360]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 49.11it/s]
# Epoch 76: 100%|██████████| 1/1 [00:00<00:00, 15.44it/s, v_num=47, train/loss_step=0.350, val/loss=1.140, val/error_u=0.850, val/error_v=1.060, val/error_h=0.743, val/loss_best=1.140, train/loss_epoch=0.355]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.54it/s]
# Epoch 77: 100%|██████████| 1/1 [00:00<00:00, 16.94it/s, v_num=47, train/loss_step=0.345, val/loss=1.130, val/error_u=0.848, val/error_v=1.060, val/error_h=0.741, val/loss_best=1.130, train/loss_epoch=0.350]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.01it/s]
# Epoch 78: 100%|██████████| 1/1 [00:00<00:00, 16.07it/s, v_num=47, train/loss_step=0.340, val/loss=1.130, val/error_u=0.847, val/error_v=1.050, val/error_h=0.739, val/loss_best=1.130, train/loss_epoch=0.345]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 54.08it/s]
# Epoch 79: 100%|██████████| 1/1 [00:00<00:00, 14.72it/s, v_num=47, train/loss_step=0.336, val/loss=1.120, val/error_u=0.845, val/error_v=1.050, val/error_h=0.737, val/loss_best=1.120, train/loss_epoch=0.340]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 48.89it/s]
# Epoch 80: 100%|██████████| 1/1 [00:00<00:00, 15.51it/s, v_num=47, train/loss_step=0.331, val/loss=1.120, val/error_u=0.844, val/error_v=1.050, val/error_h=0.735, val/loss_best=1.120, train/loss_epoch=0.336]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.96it/s]
# Epoch 81: 100%|██████████| 1/1 [00:00<00:00, 15.78it/s, v_num=47, train/loss_step=0.327, val/loss=1.110, val/error_u=0.842, val/error_v=1.040, val/error_h=0.733, val/loss_best=1.110, train/loss_epoch=0.331]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.68it/s]
# Epoch 82: 100%|██████████| 1/1 [00:00<00:00, 15.71it/s, v_num=47, train/loss_step=0.322, val/loss=1.110, val/error_u=0.841, val/error_v=1.040, val/error_h=0.731, val/loss_best=1.110, train/loss_epoch=0.327]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.89it/s]
# Epoch 83: 100%|██████████| 1/1 [00:00<00:00, 15.98it/s, v_num=47, train/loss_step=0.318, val/loss=1.100, val/error_u=0.840, val/error_v=1.040, val/error_h=0.728, val/loss_best=1.100, train/loss_epoch=0.322]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.88it/s]
# Epoch 84: 100%|██████████| 1/1 [00:00<00:00, 15.25it/s, v_num=47, train/loss_step=0.314, val/loss=1.090, val/error_u=0.839, val/error_v=1.030, val/error_h=0.726, val/loss_best=1.090, train/loss_epoch=0.318]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.29it/s]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 17.34it/s, v_num=47, train/loss_step=0.310, val/loss=1.090, val/error_u=0.838, val/error_v=1.030, val/error_h=0.724, val/loss_best=1.090, train/loss_epoch=0.314]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.29it/s]
# Epoch 86: 100%|██████████| 1/1 [00:00<00:00, 16.19it/s, v_num=47, train/loss_step=0.306, val/loss=1.080, val/error_u=0.837, val/error_v=1.030, val/error_h=0.721, val/loss_best=1.080, train/loss_epoch=0.310]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 59.51it/s]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 15.48it/s, v_num=47, train/loss_step=0.302, val/loss=1.080, val/error_u=0.836, val/error_v=1.020, val/error_h=0.719, val/loss_best=1.080, train/loss_epoch=0.306]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.37it/s]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 16.63it/s, v_num=47, train/loss_step=0.298, val/loss=1.070, val/error_u=0.835, val/error_v=1.020, val/error_h=0.717, val/loss_best=1.070, train/loss_epoch=0.302]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 49.97it/s]
# Epoch 89: 100%|██████████| 1/1 [00:00<00:00, 16.47it/s, v_num=47, train/loss_step=0.294, val/loss=1.070, val/error_u=0.833, val/error_v=1.020, val/error_h=0.714, val/loss_best=1.070, train/loss_epoch=0.298]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 48.08it/s]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 15.64it/s, v_num=47, train/loss_step=0.290, val/loss=1.060, val/error_u=0.832, val/error_v=1.010, val/error_h=0.711, val/loss_best=1.060, train/loss_epoch=0.294]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 35.39it/s]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 15.92it/s, v_num=47, train/loss_step=0.287, val/loss=1.060, val/error_u=0.831, val/error_v=1.010, val/error_h=0.709, val/loss_best=1.060, train/loss_epoch=0.290]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.02it/s]
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s, v_num=47, train/loss_step=0.283, val/loss=1.050, val/error_u=0.830, val/error_v=1.010, val/error_h=0.706, val/loss_best=1.050, train/loss_epoch=0.287]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.48it/s]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 16.17it/s, v_num=47, train/loss_step=0.279, val/loss=1.040, val/error_u=0.828, val/error_v=1.010, val/error_h=0.703, val/loss_best=1.040, train/loss_epoch=0.283]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.18it/s]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 17.75it/s, v_num=47, train/loss_step=0.276, val/loss=1.040, val/error_u=0.827, val/error_v=1.010, val/error_h=0.701, val/loss_best=1.040, train/loss_epoch=0.279]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.69it/s]
# Epoch 95: 100%|██████████| 1/1 [00:00<00:00, 16.07it/s, v_num=47, train/loss_step=0.272, val/loss=1.030, val/error_u=0.826, val/error_v=1.000, val/error_h=0.698, val/loss_best=1.030, train/loss_epoch=0.276]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 56.96it/s]
# Epoch 96: 100%|██████████| 1/1 [00:00<00:00, 16.36it/s, v_num=47, train/loss_step=0.268, val/loss=1.030, val/error_u=0.825, val/error_v=1.000, val/error_h=0.696, val/loss_best=1.030, train/loss_epoch=0.272]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.94it/s]
# Epoch 97: 100%|██████████| 1/1 [00:00<00:00, 16.96it/s, v_num=47, train/loss_step=0.265, val/loss=1.030, val/error_u=0.825, val/error_v=1.000, val/error_h=0.693, val/loss_best=1.030, train/loss_epoch=0.268]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.94it/s]
# Epoch 98: 100%|██████████| 1/1 [00:00<00:00, 15.87it/s, v_num=47, train/loss_step=0.262, val/loss=1.020, val/error_u=0.823, val/error_v=0.998, val/error_h=0.690, val/loss_best=1.020, train/loss_epoch=0.265]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.56it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 17.43it/s, v_num=47, train/loss_step=0.258, val/loss=1.010, val/error_u=0.823, val/error_v=0.996, val/error_h=0.687, val/loss_best=1.010, train/loss_epoch=0.262]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 53.89it/s]
# Epoch 100: 100%|██████████| 1/1 [00:00<00:00, 15.59it/s, v_num=47, train/loss_step=0.255, val/loss=1.010, val/error_u=0.822, val/error_v=0.994, val/error_h=0.685, val/loss_best=1.010, train/loss_epoch=0.258]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.43it/s]
# Epoch 101: 100%|██████████| 1/1 [00:00<00:00, 15.37it/s, v_num=47, train/loss_step=0.252, val/loss=1.000, val/error_u=0.821, val/error_v=0.992, val/error_h=0.682, val/loss_best=1.000, train/loss_epoch=0.255]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.64it/s]
# Epoch 102: 100%|██████████| 1/1 [00:00<00:00, 15.69it/s, v_num=47, train/loss_step=0.248, val/loss=1.000, val/error_u=0.820, val/error_v=0.990, val/error_h=0.679, val/loss_best=1.000, train/loss_epoch=0.252]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# Epoch 103: 100%|██████████| 1/1 [00:00<00:00, 16.18it/s, v_num=47, train/loss_step=0.245, val/loss=0.995, val/error_u=0.819, val/error_v=0.989, val/error_h=0.676, val/loss_best=0.995, train/loss_epoch=0.248]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 63.82it/s]
# Epoch 104: 100%|██████████| 1/1 [00:00<00:00, 15.78it/s, v_num=47, train/loss_step=0.242, val/loss=0.990, val/error_u=0.818, val/error_v=0.987, val/error_h=0.673, val/loss_best=0.990, train/loss_epoch=0.245]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.04it/s]
# Epoch 105: 100%|██████████| 1/1 [00:00<00:00, 17.13it/s, v_num=47, train/loss_step=0.239, val/loss=0.986, val/error_u=0.817, val/error_v=0.986, val/error_h=0.671, val/loss_best=0.986, train/loss_epoch=0.242]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.87it/s]
# Epoch 965: 100%|██████████| 1/1 [00:00<00:00, 17.39it/s, v_num=47, train/loss_step=0.0329, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.036]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 52.21it/s]
# Epoch 966: 100%|██████████| 1/1 [00:00<00:00, 17.16it/s, v_num=47, train/loss_step=0.0291, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0329]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 80.23it/s]
# Epoch 967: 100%|██████████| 1/1 [00:00<00:00, 17.45it/s, v_num=47, train/loss_step=0.0284, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0291]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.16it/s]
# Epoch 968: 100%|██████████| 1/1 [00:00<00:00, 17.51it/s, v_num=47, train/loss_step=0.0305, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0284]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 66.86it/s]
# Epoch 969: 100%|██████████| 1/1 [00:00<00:00, 17.19it/s, v_num=47, train/loss_step=0.0321, val/loss=1.150, val/error_u=1.060, val/error_v=1.270, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0305]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.38it/s]
# Epoch 970: 100%|██████████| 1/1 [00:00<00:00, 17.05it/s, v_num=47, train/loss_step=0.0314, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.359, val/loss_best=0.823, train/loss_epoch=0.0321]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.45it/s]
# Epoch 971: 100%|██████████| 1/1 [00:00<00:00, 18.00it/s, v_num=47, train/loss_step=0.0293, val/loss=1.150, val/error_u=1.060, val/error_v=1.270, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0314]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 58.55it/s]
# Epoch 972: 100%|██████████| 1/1 [00:00<00:00, 17.09it/s, v_num=47, train/loss_step=0.0284, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0293]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 82.37it/s]
# Epoch 973: 100%|██████████| 1/1 [00:00<00:00, 17.51it/s, v_num=47, train/loss_step=0.0294, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0284]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.44it/s]
# Epoch 974: 100%|██████████| 1/1 [00:00<00:00, 17.56it/s, v_num=47, train/loss_step=0.0306, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0294]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 82.73it/s]
# Epoch 975: 100%|██████████| 1/1 [00:00<00:00, 17.06it/s, v_num=47, train/loss_step=0.0305, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0306]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.16it/s]
# Epoch 976: 100%|██████████| 1/1 [00:00<00:00, 18.04it/s, v_num=47, train/loss_step=0.0297, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.359, val/loss_best=0.823, train/loss_epoch=0.0305]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 76.46it/s]
# Epoch 977: 100%|██████████| 1/1 [00:00<00:00, 17.19it/s, v_num=47, train/loss_step=0.0297, val/loss=1.150, val/error_u=1.060, val/error_v=1.270, val/error_h=0.356, val/loss_best=0.823, train/loss_epoch=0.0297]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.78it/s]
# Epoch 978: 100%|██████████| 1/1 [00:00<00:00, 16.64it/s, v_num=47, train/loss_step=0.0312, val/loss=1.140, val/error_u=1.060, val/error_v=1.250, val/error_h=0.360, val/loss_best=0.823, train/loss_epoch=0.0297]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.22it/s]
# Epoch 979: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s, v_num=47, train/loss_step=0.0335, val/loss=1.160, val/error_u=1.070, val/error_v=1.270, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.0312]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.89it/s]
# Epoch 980: 100%|██████████| 1/1 [00:00<00:00, 17.03it/s, v_num=47, train/loss_step=0.0354, val/loss=1.130, val/error_u=1.060, val/error_v=1.250, val/error_h=0.361, val/loss_best=0.823, train/loss_epoch=0.0335]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.09it/s]
# Epoch 981: 100%|██████████| 1/1 [00:00<00:00, 16.62it/s, v_num=47, train/loss_step=0.0369, val/loss=1.160, val/error_u=1.070, val/error_v=1.280, val/error_h=0.354, val/loss_best=0.823, train/loss_epoch=0.0354]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.51it/s]
# Epoch 982: 100%|██████████| 1/1 [00:00<00:00, 17.11it/s, v_num=47, train/loss_step=0.0375, val/loss=1.130, val/error_u=1.060, val/error_v=1.250, val/error_h=0.361, val/loss_best=0.823, train/loss_epoch=0.0369]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 57.97it/s]
# Epoch 983: 100%|██████████| 1/1 [00:00<00:00, 16.86it/s, v_num=47, train/loss_step=0.0362, val/loss=1.160, val/error_u=1.070, val/error_v=1.270, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.0375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 70.47it/s]
# Epoch 984: 100%|██████████| 1/1 [00:00<00:00, 16.88it/s, v_num=47, train/loss_step=0.0337, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.359, val/loss_best=0.823, train/loss_epoch=0.0362]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 64.27it/s]
# Epoch 985: 100%|██████████| 1/1 [00:00<00:00, 15.91it/s, v_num=47, train/loss_step=0.0309, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0337]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 74.29it/s]
# Epoch 986: 100%|██████████| 1/1 [00:00<00:00, 17.46it/s, v_num=47, train/loss_step=0.0297, val/loss=1.150, val/error_u=1.060, val/error_v=1.270, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0309]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.39it/s]
# Epoch 987: 100%|██████████| 1/1 [00:00<00:00, 16.72it/s, v_num=47, train/loss_step=0.030, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.359, val/loss_best=0.823, train/loss_epoch=0.0297]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 77.09it/s]
# Epoch 988: 100%|██████████| 1/1 [00:00<00:00, 15.63it/s, v_num=47, train/loss_step=0.0312, val/loss=1.160, val/error_u=1.070, val/error_v=1.270, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.030]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 65.81it/s]
# Epoch 989: 100%|██████████| 1/1 [00:00<00:00, 16.12it/s, v_num=47, train/loss_step=0.032, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.359, val/loss_best=0.823, train/loss_epoch=0.0312]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 73.03it/s]
# Epoch 990: 100%|██████████| 1/1 [00:00<00:00, 16.32it/s, v_num=47, train/loss_step=0.0315, val/loss=1.150, val/error_u=1.070, val/error_v=1.260, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.032]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 61.88it/s]
# Epoch 991: 100%|██████████| 1/1 [00:00<00:00, 16.51it/s, v_num=47, train/loss_step=0.0304, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0315]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 82.14it/s]
# Epoch 992: 100%|██████████| 1/1 [00:00<00:00, 18.29it/s, v_num=47, train/loss_step=0.0293, val/loss=1.150, val/error_u=1.070, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0304]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 68.62it/s]
# Epoch 993: 100%|██████████| 1/1 [00:00<00:00, 18.33it/s, v_num=47, train/loss_step=0.0293, val/loss=1.150, val/error_u=1.060, val/error_v=1.270, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0293]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.86it/s]
# Epoch 994: 100%|██████████| 1/1 [00:00<00:00, 16.06it/s, v_num=47, train/loss_step=0.0301, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0293]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 78.98it/s]
# Epoch 995: 100%|██████████| 1/1 [00:00<00:00, 16.48it/s, v_num=47, train/loss_step=0.0309, val/loss=1.150, val/error_u=1.070, val/error_v=1.270, val/error_h=0.356, val/loss_best=0.823, train/loss_epoch=0.0301]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 72.30it/s]
# Epoch 996: 100%|██████████| 1/1 [00:00<00:00, 17.28it/s, v_num=47, train/loss_step=0.031, val/loss=1.150, val/error_u=1.070, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.0309]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 62.84it/s]
# Epoch 997: 100%|██████████| 1/1 [00:00<00:00, 16.51it/s, v_num=47, train/loss_step=0.0305, val/loss=1.150, val/error_u=1.060, val/error_v=1.260, val/error_h=0.357, val/loss_best=0.823, train/loss_epoch=0.031]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 69.82it/s]
# Epoch 998: 100%|██████████| 1/1 [00:00<00:00, 17.81it/s, v_num=47, train/loss_step=0.0304, val/loss=1.150, val/error_u=1.070, val/error_v=1.260, val/error_h=0.356, val/loss_best=0.823, train/loss_epoch=0.0305]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 49.93it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s, v_num=47, train/loss_step=0.031, val/loss=1.140, val/error_u=1.060, val/error_v=1.260, val/error_h=0.358, val/loss_best=0.823, train/loss_epoch=0.0304]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 67.30it/s]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 10.25it/s, v_num=47, train/loss_step=0.031, val/loss=1.160, val/error_u=1.070, val/error_v=1.260, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.031]
# `Trainer.fit` stopped: `max_epochs=1000` reached.
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00,  9.28it/s, v_num=47, train/loss_step=0.031, val/loss=1.160, val/error_u=1.070, val/error_v=1.260, val/error_h=0.355, val/loss_best=0.823, train/loss_epoch=0.031]
# CPU times: total: 1min 55s
# Wall time: 2min

# %% [markdown]
# ### Validation

# %%
trainer.validate(model=model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 11.97it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        val/error_h        │    0.3552889823913574     │
# │        val/error_u        │    1.0736390352249146     │
# │        val/error_v        │    1.2612165212631226     │
# │         val/loss          │    1.1556400060653687     │
# │       val/loss_best       │    0.8229885101318359     │
# └───────────────────────────┴───────────────────────────┘
# [{'val/loss': 1.1556400060653687,
#   'val/error_u': 1.0736390352249146,
#   'val/error_v': 1.2612165212631226,
#   'val/error_h': 0.3552889823913574,
#   'val/loss_best': 0.8229885101318359}]

# %% [markdown]
# ### Plotting
#
# For plotting, we need predict the results, and then, we should concatenate the results.

# %%
preds_list = trainer.predict(model=model, datamodule=datamodule)
preds_dict = pinnstorch.utils.fix_predictions(preds_list)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 13.10it/s]

# %%
pinnstorch.utils.plot_schrodinger(mesh=mesh,
                                  preds=preds_dict,
                                  train_datasets=train_datasets,
                                  val_dataset=val_dataset,
                                  file_name='out')
